# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
import time
from geopy import geocoders

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# List of each week number
weeks = list(range(1,18))
# Api Url
base_url = "http://api.fantasy.nfl.com/v1/players/stats?statType=weekStats&season=2018&week={}&form=json"

# %%
# Empty dataframe to contain all the api data
temp_final_df = pd.DataFrame()

# %%
# Makes an api call for each week's data and appends it to main dataframe
for week in weeks:
    target_url = base_url.format(week)
    temp = requests.get(target_url).json()['players']
    temp_df = pd.DataFrame(temp)
    temp_df = temp_df.drop(columns = 'stats')
    temp_df['week'] = week
    temp_final_df = temp_final_df.append(temp_df)

# %%
temp_final_df[temp_final_df['week'] == 1]
team_names = temp_final_df.teamAbbr.unique()
team_names
# Out:
# array(['SF', 'GB', 'NYJ', 'CAR', 'LAC', 'PHI', 'DET', 'MIA', 'HOU', 'TB',
#        'BUF', 'ATL', 'BAL', 'WAS', 'PIT', 'CHI', 'LA', 'NO', 'DAL', 'CLE',
#        'CIN', 'IND', 'KC', 'ARI', 'SEA', 'NYG', 'MIN', 'DEN', 'TEN', 'NE',
#        'OAK', 'JAX', ''], dtype=object)

# %%
data = pd.read_csv('2018_Schedule_City.csv')

# %%
import time
from datetime import datetime
date_str2 = '6/6/18'
date_dt2 = datetime.strptime(date_str2, '%m/%d/%y')
date_dt2
# Out:
# datetime.datetime(2018, 6, 6, 0, 0)

# %%
data['away_abrev'] = data['Away'].str[0:4]
data['home_abrev'] = data['Home'].str[0:4]
data
# Out:
#            Date                    Away                   Home  \
# 0      9/6/2018        Atlanta Falcons     Philadelphia Eagles
# 1      9/9/2018          Buffalo Bills        Baltimore Ravens
# 2      9/9/2018     Cincinnati Bengals      Indianapolis Colts
# 3      9/9/2018         Houston Texans    New England Patriots
# 4      9/9/2018   Jacksonville Jaguars         New York Giants
# 5      9/9/2018    Pittsburgh Steelers        Cleveland Browns
# 6      9/9/2018    San Francisco 49ers       Minnesota Vikings
# 7      9/9/2018   Tampa Bay Buccaneers      New Orleans Saints
# 8      9/9/2018       Tennessee Titans          Miami Dolphins
# 9      9/9/2018     Kansas City Chiefs    Los Angeles Chargers
# 10     9/9/2018         Dallas Cowboys       Carolina Panthers
# 11     9/9/2018       Seattle Seahawks          Denver Broncos
# 12     9/9/2018    Washington Redskins       Arizona Cardinals
# 13     9/9/2018          Chicago Bears       Green Bay Packers
# 14    9/10/2018          New York Jets           Detroit Lions
# 15    9/10/2018       Los Angeles Rams         Oakland Raiders
# 16    9/13/2018       Baltimore Ravens      Cincinnati Bengals
# 17    9/16/2018      Carolina Panthers         Atlanta Falcons
# 18    9/16/2018       Cleveland Browns      New Orleans Saints
# 19    9/16/2018         Houston Texans        Tennessee Titans
# 20    9/16/2018     Indianapolis Colts     Washington Redskins
# 21    9/16/2018     Kansas City Chiefs     Pittsburgh Steelers
# 22    9/16/2018   Los Angeles Chargers           Buffalo Bills
# 23    9/16/2018         Miami Dolphins           New York Jets
# 24    9/16/2018      Minnesota Vikings       Green Bay Packers
# 242               U.S. Bank Stadium, Minneapolis    17      Minneapolis, MN
# 243                      Heinz Field, Pittsburgh    17       Pittsburgh, PA
# 244                  M&T Bank Stadium, Baltimore    17        Baltimore, MD
# 245             MetLife Stadium, East Rutherford    17  East Rutherford, NY
# 246                     Lambeau Field, Green Bay    17        Green Bay, WI
# 247                    Nissan Stadium, Nashville    17        Nashville, TN
# 248                         NRG Stadium, Houston    17          Houston, TX
# 249                       New Era Field, Buffalo    17          Buffalo, NY
# 250                    Gillette Stadium, Foxboro    17          Foxboro, MA
# 251               Arrowhead Stadium, Kansas City    17      Kansas City, MO
# 252                        FedEx Field, Landover    17         Landover, MD
# 253                   CenturyLink Field, Seattle    17          Seattle, WA
# 254  Sports Authority Field at Mile High, Denver    17           Denver, CO
# 255   Los Angeles Memorial Coliseum, Los Angeles    17      Los Angeles, CA
#
#     away_abrev home_abrev
# 0          Atl        Phi
# 1          Buf        Bal
# 2          Cin        Ind
# 3          Hou        New
# 4          Jac        New
# 5          Pit        Cle
# 6          San        Min
# 7          Tam        New
# 8          Ten        Mia
# 9          Kan        Los
# 10         Dal        Car
# 11         Sea        Den
# 12         Was        Ari
# 13         Chi        Gre
# 14         New        Det
# 15         Los        Oak
# 16         Bal        Cin
# 17         Car        Atl
# 18         Cle        New
# 19         Hou        Ten
# 20         Ind        Was
# 21         Kan        Pit
# 22         Los        Buf
# 23         Mia        New
# 24         Min        Gre
# 25         Phi        Tam
# 26         Ari        Los
# 27         Det        San
# 28         New        Jac
# 29         Oak        Den
# ..         ...        ...
# 226        Cin        Cle
# 227        Gre        New
# 228        Hou        Phi
# 229        Jac        Mia
# 230        Min        Det
# 231        New        Ind
# 232        Tam        Dal
# 233        Was        Ten
# 234        Bal        Los
# 235        Chi        San
# 236        Los        Ari
# 237        Pit        New
# 238        Kan        Sea
# 239        Den        Oak
# 240        Atl        Tam
# 241        Car        New
# 242        Chi        Min
# 243        Cin        Pit
# 244        Cle        Bal
# 245        Dal        New
# 246        Det        Gre
# 247        Ind        Ten
# 248        Jac        Hou
# 249        Mia        Buf
# 250        New        New
# 251        Oak        Kan
# 252        Phi        Was
# 253        Ari        Sea
# 254        Los        Den
# 255        San        Los
#
# [256 rows x 10 columns]

# %%
away_abrev = []

for awy in data['away_abrev']:
    away_abrev.append(process.extract(awy,team_names)[0][0])

# %%
home_abrev = []

for hme in data['home_abrev']:
    home_abrev.append(process.extract(hme,team_names)[0][0])

# %%
# Out:
# ['PHI',
#  'BAL',
#  'IND',
#  'NE',
#  'NE',
#  'CLE',
#  'MIN',
#  'NE',
#  'MIA',
#  'SF',
#  'CAR',
#  'DEN',
#  'ARI',
#  'GB',
#  'DET',
#  'OAK',
#  'CIN',
#  'ATL',
#  'NE',
#  'TEN',
#  'WAS',
#  'PIT',
#  'BUF',
#  'NE',
#  'GB',
#  'TB',
#  'SF',
#  'SEA',
#  'LAC',
#  'DEN',
#  'DAL',
#  'CHI',
#  'CLE',
#  'MIN',
#  'CAR',
#  'BAL',
#  'WAS',
#  'PHI',
#  'ATL',
#  'HOU',
#  'MIA',
#  'NO',
#  'LAC',
#  'SF',
#  'ARI',
#  'SEA',
#  'DET',
#  'TB',
#  'SF',
#  'GB',
#  'ATL',
#  'DAL',
#  'IND',
#  'NE',
#  'LAC',
#  'TEN',
#  'CHI',
#  'OAK',
#  'ARI',
#  'NE',
#  'SF',
#  'PIT',
#  'DEN',
#  'NE',
#  'PIT',
#  'CLE',
#  'NE',
#  'DET',
#  'NO',
#  'CIN',
#  'CAR',
#  'BUF',
#  'SF',
#  'SEA',
#  'SEA',
#  'PHI',
#  'HOU',
#  'NE',
#  'NE',
#  'MIN',
#  'HOU',
#  'WAS',
#  'MIA',
#  'NE',
#  'CLE',
#  'CIN',
#  'OAK',
#  'ATL',
#  'DEN',
#  'TEN',
#  'DAL',
#  'NE',
#  'GB',
#  'ARI',
#  'SF',
#  'IND',
#  'PHI',
#  'NO',
#  'TB',
#  'MIA',
#  'LAC',
#  'NE',
#  'CHI',
#  'BAL',
#  'WAS',
#  'SEA',
#  'ATL',
#  'HOU',
#  'LAC',
#  'CAR',
#  'PIT',
#  'NO',
#  'CHI',
#  'DET',
#  'CIN',
#  'NE',
#  'OAK',
#  'SF',
#  'ARI',
#  'MIN',
#  'BUF',
#  'SEA',
#  'WAS',
#  'BUF',
#  'MIN',
#  'CLE',
#  'MIA',
#  'BAL',
#  'CAR',
#  'DEN',
#  'SEA',
#  'NE',
#  'NE',
#  'DAL',
#  'PIT',
#  'NO',
#  'CLE',
#  'NE',
#  'CHI',
#  'IND',
#  'GB',
#  'TEN',
#  'CIN',
#  'TB',
#  'OAK',
#  'SF',
#  'PHI',
#  'SEA',
#  'SEA',
#  'DET',
#  'BAL',
#  'ATL',
#  'WAS',
#  'CHI',
#  'NE',
#  'NE',
#  'IND',
#  'SF',
#  'ARI',
#  'LAC',
#  'SF',
#  'DET',
#  'DAL',
#  'NE',
#  'CIN',
#  'BUF',
#  'IND',
#  'NE',
#  'PHI',
#  'BAL',
#  'TB',
#  'CAR',
#  'SF',
#  'DEN',
#  'MIN',
#  'HOU',
#  'DAL',
#  'GB',
#  'ATL',
#  'MIA',
#  'TB',
#  'NE',
#  'HOU',
#  'CIN',
#  'LAC',
#  'PIT',
#  'DET',
#  'OAK',
#  'TEN',
#  'NE',
#  'SEA',
#  'PHI',
#  'TEN',
#  'GB',
#  'NO',
#  'CLE',
#  'HOU',
#  'CHI',
#  'MIA',
#  'TB',
#  'WAS',
#  'BUF',
#  'SF',
#  'SEA',
#  'ARI',
#  'DAL',
#  'OAK',
#  'SEA',
#  'NO',
#  'DEN',
#  'NE',
#  'ATL',
#  'IND',
#  'BUF',
#  'CHI',
#  'MIN',
#  'CIN',
#  'BAL',
#  'NE',
#  'LAC',
#  'SEA',
#  'PIT',
#  'SF',
#  'CAR',
#  'CAR',
#  'NE',
#  'CLE',
#  'NE',
#  'PHI',
#  'MIA',
#  'DET',
#  'IND',
#  'DAL',
#  'TEN',
#  'SF',
#  'SEA',
#  'ARI',
#  'NE',
#  'SEA',
#  'OAK',
#  'TB',
#  'NE',
#  'MIN',
#  'PIT',
#  'BAL',
#  'NE',
#  'GB',
#  'TEN',
#  'HOU',
#  'BUF',
#  'NE',
#  'NO',
#  'WAS',
#  'SEA',
#  'DEN',
#  'SF']

# %%
data['away_abrev'] = away_abrev
data['home_abrev'] = home_abrev
data
# Out:
#            Date                    Away                   Home  \
# 0      9/6/2018        Atlanta Falcons     Philadelphia Eagles
# 1      9/9/2018          Buffalo Bills        Baltimore Ravens
# 2      9/9/2018     Cincinnati Bengals      Indianapolis Colts
# 3      9/9/2018         Houston Texans    New England Patriots
# 4      9/9/2018   Jacksonville Jaguars         New York Giants
# 5      9/9/2018    Pittsburgh Steelers        Cleveland Browns
# 6      9/9/2018    San Francisco 49ers       Minnesota Vikings
# 7      9/9/2018   Tampa Bay Buccaneers      New Orleans Saints
# 8      9/9/2018       Tennessee Titans          Miami Dolphins
# 9      9/9/2018     Kansas City Chiefs    Los Angeles Chargers
# 10     9/9/2018         Dallas Cowboys       Carolina Panthers
# 11     9/9/2018       Seattle Seahawks          Denver Broncos
# 12     9/9/2018    Washington Redskins       Arizona Cardinals
# 13     9/9/2018          Chicago Bears       Green Bay Packers
# 14    9/10/2018          New York Jets           Detroit Lions
# 15    9/10/2018       Los Angeles Rams         Oakland Raiders
# 16    9/13/2018       Baltimore Ravens      Cincinnati Bengals
# 17    9/16/2018      Carolina Panthers         Atlanta Falcons
# 18    9/16/2018       Cleveland Browns      New Orleans Saints
# 19    9/16/2018         Houston Texans        Tennessee Titans
# 20    9/16/2018     Indianapolis Colts     Washington Redskins
# 21    9/16/2018     Kansas City Chiefs     Pittsburgh Steelers
# 22    9/16/2018   Los Angeles Chargers           Buffalo Bills
# 23    9/16/2018         Miami Dolphins           New York Jets
# 24    9/16/2018      Minnesota Vikings       Green Bay Packers
# 25    9/16/2018    Philadelphia Eagles    Tampa Bay Buccaneers
# 26    9/16/2018      Arizona Cardinals        Los Angeles Rams
# 27    9/16/2018          Detroit Lions     San Francisco 49ers
# 28    9/16/2018   New England Patriots    Jacksonville Jaguars
# 29    9/16/2018        Oakland Raiders          Denver Broncos
# ..          ...                     ...                    ...
# 226  12/23/2018     Cincinnati Bengals        Cleveland Browns
# 227  12/23/2018      Green Bay Packers           New York Jets
# 228  12/23/2018         Houston Texans     Philadelphia Eagles
# 229  12/23/2018   Jacksonville Jaguars          Miami Dolphins
# 230  12/23/2018      Minnesota Vikings           Detroit Lions
# 231  12/23/2018        New York Giants      Indianapolis Colts
# 232  12/23/2018   Tampa Bay Buccaneers          Dallas Cowboys
# 233  12/23/2018    Washington Redskins        Tennessee Titans
# 255   Los Angeles Memorial Coliseum, Los Angeles    17      Los Angeles, CA
#
#     away_abrev home_abrev
# 0          ATL        PHI
# 1          BUF        BAL
# 2          CIN        IND
# 3          HOU         NE
# 4          LAC         NE
# 5          PIT        CLE
# 6          SEA        MIN
# 7           TB         NE
# 8          TEN        MIA
# 9           NO         SF
# 10         DAL        CAR
# 11         SEA        DEN
# 12         WAS        ARI
# 13         CHI         GB
# 14          NE        DET
# 15          SF        OAK
# 16         BAL        CIN
# 17         CAR        ATL
# 18         CLE         NE
# 19         HOU        TEN
# 20         IND        WAS
# 21          NO        PIT
# 22          SF        BUF
# 23         MIA         NE
# 24         MIN         GB
# 25         PHI         TB
# 26         ARI         SF
# 27         DET        SEA
# 28          NE        LAC
# 29         OAK        DEN
# ..         ...        ...
# 226        CIN        CLE
# 227         GB         NE
# 228        HOU        PHI
# 229        LAC        MIA
# 230        MIN        DET
# 231         NE        IND
# 232         TB        DAL
# 233        WAS        TEN
# 234        BAL         SF
# 235        CHI        SEA
# 236         SF        ARI
# 237        PIT         NE
# 238         NO        SEA
# 239        DEN        OAK
# 240        ATL         TB
# 241        CAR         NE
# 242        CHI        MIN
# 243        CIN        PIT
# 244        CLE        BAL
# 245        DAL         NE
# 246        DET         GB
# 247        IND        TEN
# 248        LAC        HOU
# 249        MIA        BUF
# 250         NE         NE
# 251        OAK         NO
# 252        PHI        WAS
# 253        ARI        SEA
# 254         SF        DEN
# 255        SEA         SF
#
# [256 rows x 10 columns]

# %%
city_list = data['City'].tolist()
city_weather = {}
loc = geolocator.geocode(city_list[0])
loc.address
# Out:
# 'Philadelphia, Philadelphia County, Pennsylvania, USA'

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode(data['City'][0])
print(location.address)
print(geolocator.geocode(data['City'][0]).address)
# Out:
# Philadelphia, Philadelphia County, Pennsylvania, USA
# Philadelphia, Philadelphia County, Pennsylvania, USA

# %% [markdown]
# for city in city_list:
#     loc = geolocator.geocode(city)
#     city_weather[city] = geolocator.geocode(loc.address)

# %% [markdown]
# city_weather

# %%
data['City'][0]

# %%
# Base url used to access the openweathermap api 
url = "http://api.openweathermap.org/data/2.5/weather?"
# Url used to actually access the api data using the provided api key
query_url = f"{url}appid={api_key}&units=imperial&q="

# %%
response = requests.get(query_url + location.address)

# %%
print(response)

# %% [markdown]
# response.json()

# %%
# Base url used to access the openweathermap api 
url = "http://api.openweathermap.org/data/2.5/weather?"
# Url used to actually access the api data using the provided api key
query_url = f"{url}appid={api_key}&units=imperial&q="

# Counter used to count the amount of records being called from openweathermap's api
rec_count = 0
# Empty list to store the each city's weather data
city_data = []

print("Beginning Data Retrieval")    
print("-----------------------------")
# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city)
    
    # If statement used to determine wether the pull was successful and add that to the city_data list
    if str(response) == "<Response [200]>":
        rec_count +=1
        print(f"Processing Record {rec_count} of Set 1 | {city}")
        city_data.append(response.json())
    
    # Prints if there is no data on that city and leaves out the city name
    else:
        print("City not found. Skipping...")
