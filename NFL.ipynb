# %%
from bs4 import BeautifulSoup as bs
import requests
import os
import pandas as pd
import pymongo
from splinter import Browser

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
receivingURL = 'https://nextgenstats.nfl.com/stats/receiving#yards'
browser.visit(receivingURL)
html = browser.html
soup = bs(html, 'html.parser')

# %%
receivingtable=pd.read_html(str(soup.find_all('table')))
recdf= pd.DataFrame(receivingtable[1])
reccolumnlist = receivingtable[0].values.tolist()[0]
reccolumnlist.pop()
#for i in reccolumnlist:
 #   i.replace('.','')
recdf.columns = reccolumnlist
recdf = recdf.rename(index=str, columns={"+/-Avg .YAC Above Expectation":"+/-Avg YAC Above Expectation"})
recdf
# Out:
#              PLAYER NAME TEAM POS  CUSHAverage Cushion (CUSH)  \
# 0            Julio Jones  ATL  WR                         5.7
# 1        DeAndre Hopkins  HOU  WR                         4.9
# 2             Mike Evans   TB  WR                         5.7
# 3            Tyreek Hill   KC  WR                         5.9
# 4         Michael Thomas   NO  WR                         4.6
# 5          Davante Adams   GB  WR                         4.8
# 6    JuJu Smith-Schuster  PIT  WR                         5.3
# 7          George Kittle   SF  TE                         5.4
# 8           Adam Thielen  MIN  WR                         5.8
# 9           Travis Kelce   KC  TE                         5.6
# 10         Antonio Brown  PIT  WR                         5.0
# 11           T.Y. Hilton  IND  WR                         5.9
# 12          Robert Woods  LAR  WR                         6.4
# 13         Brandin Cooks  LAR  WR                         5.7
# 14          Keenan Allen  LAC  WR                         5.3
# 15             Zach Ertz  PHI  TE                         6.1
# 16        Kenny Golladay  DET  WR                         4.9
# 17         Odell Beckham  NYG  WR                         6.2
# 18            Tyler Boyd  CIN  WR                         5.6
# 19          Stefon Diggs  MIN  WR                         5.9
# 20          Amari Cooper  DAL  WR                         6.0
# 21         Jarvis Landry  CLE  WR                         5.7
# 22         Tyler Lockett  SEA  WR                         6.6
# 23            Jared Cook  OAK  TE                         5.6
# 24           Corey Davis  TEN  WR                         6.1
# 25      Sterling Shepard  NYG  WR                         5.9
# 26      Emmanuel Sanders  DEN  WR                         6.2
# 27        Julian Edelman   NE  WR                         6.2
# 28          Chris Godwin   TB  WR                         6.2
# 29        Alshon Jeffery  PHI  WR                         5.5
# ..                   ...  ...  ..                         ...
# 95        Tre'Quan Smith   NO  WR                         5.6
# 96        Anthony Miller  CHI  WR                         5.2
# 97         Josh Reynolds  LAR  WR                         7.5
# 98       Benjamin Watson   NO  TE                         5.4
# 99      Marquise Goodwin   SF  WR                         5.8
# 100      Jamison Crowder  WAS  WR                         6.4
# 101         Randall Cobb   GB  WR                         5.4
# 102      Kelvin Benjamin   KC  WR                         5.5
# 103      Jermaine Kearse  NYJ  WR                         6.4
# 104    Ricky Seals-Jones  ARI  TE                         5.3
# 105         Chris Conley   KC  WR                         6.5
# 106           Ryan Grant  IND  WR                         5.7
# 107       Dallas Goedert  PHI  TE                         5.2
# 108           Ian Thomas  CAR  TE                         6.0
# 109        Antonio Gates  LAC  TE                         4.4
# 110         Tajae Sharpe  TEN  WR                         6.2
# 111       Gerald Everett  LAR  TE                         6.0
# 112       DeVante Parker  MIA  WR                         5.2
# 113         Ryan Griffin  HOU  TE                         5.1
# 114       Maurice Harris  WAS  WR                         6.6
# 115     Laquon Treadwell  MIN  WR                         6.3
# 116        Cameron Brate   TB  TE                         5.6
# 117        Pierre Garcon   SF  WR                         5.6
# 118        Jeff Heuerman  DEN  TE                         5.7
# 119         Nick Vannett  SEA  TE                         5.7
# 120          Zach Pascal  IND  WR                         5.7
# 121         Ryan Switzer  PIT  WR                         5.8
# 122     DaeSean Hamilton  DEN  WR                         5.3
# 123            John Ross  CIN  WR                         5.4
# 124        Chad Williams  ARI  WR                         5.4
#
#      SEPAverage Separation (SEP)  TAYAverage Targeted Air Yards (TAY)  \
# 0                            2.5                                 14.0
# 1                            2.5                                 11.9
# 2                            2.1                                 15.7
# 3                            3.1                                 14.8
# 4                            2.7                                  7.7
# 5                            3.0                                 11.3
# 6                            3.0                                  8.7
# 7                            3.3                                  7.3
# 8                            2.9                                  9.6
# 9                            2.9                                  8.9
# 10                           2.6                                 11.2
# 11                           2.3                                 11.3
# 12                           3.0                                 11.3
# 13                           2.7                                 12.9
# 14                           2.7                                  8.8
# 15                           3.2                                  7.3
# 16                           2.3                                 12.6
# 17                           3.0                                 11.5
# 18                           2.9                                  9.4
# 19                           2.7                                  8.9
# 20                           2.9                                  9.9
# 21                           3.3                                 10.8
# 22                           3.3                                 13.5
# 23                           3.0                                  8.0
# 24                           3.1                                 10.3
# 25                           3.1                                 10.4
# 26                           3.2                                  9.3
# 27                           3.3                                  7.7
# 28                           2.6                                 11.9
# 29                           2.5                                 10.8
# ..                           ...                                  ...
# 95                           2.2                                 12.1
# 96                           3.0                                 11.3
# 97                           3.0                                 12.9
# 98                           2.6                                  9.9
# 99                           3.0                                 14.2
# 100                          2.9                                  9.1
# 101                          2.9                                  8.2
# 102                          1.7                                 15.9
# 103                          2.7                                  9.3
# 104                          2.7                                  9.8
# 105                          3.3                                  9.6
# 106                          2.6                                  9.5
# 107                          3.3                                  7.7
# 108                          3.4                                  6.3
# 109                          2.5                                  8.8
# 110                          3.0                                 11.3
# 111                          3.9                                  6.6
# 112                          2.7                                 11.6
# 113                          3.4                                  7.9
# 114                          3.1                                 10.5
# 115                          2.9                                  5.9
# 116                          2.9                                  8.7
# 117                          2.8                                  8.8
# 118                          3.3                                  5.7
# 119                          3.7                                  6.1
# 120                          2.4                                  9.6
# 121                          3.5                                  3.2
# 122                          3.1                                  8.4
# 123                          2.2                                 14.0
# 124                          1.9                                 13.2
#
#      TAY%% Share of Team's Air Yards (TAY%)  RECReceptions (REC)  \
# 0                                     45.64                  113
# 1                                     44.04                  115
# 2                                     32.83                   86
# 3                                     38.19                   87
# 4                                     30.26                  125
# 5                                     33.97                  111
# 6                                     27.73                  111
# 7                                     25.32                   88
# 8                                     32.77                  113
# 9                                     25.12                  103
# 10                                    36.01                  104
# 11                                    27.57                   76
# 12                                    29.84                   86
# 13                                    30.80                   80
# 14                                    29.75                   97
# 15                                    25.85                  116
# 16                                    37.34                   70
# 17                                    33.29                   77
# 18                                    22.95                   76
# 19                                    29.56                  102
# 20                                    28.97                   75
# 21                                    30.30                   81
# 22                                    24.40                   57
# 23                                    22.13                   68
# 24                                    35.88                   65
# 25                                    25.98                   66
# 26                                    20.87                   71
# 27                                    19.21                   74
# 28                                    17.14                   59
# 29                                    22.67                   65
# ..                                      ...                  ...
# 95                                    14.26                   28
# 96                                    13.71                   33
# 97                                    13.64                   29
# 98                                    12.21                   35
# 99                                    15.89                   23
# 100                                   10.71                   29
# 101                                    8.84                   38
# 102                                   21.41                   25
# 103                                   15.34                   37
# 104                                   17.05                   34
# 105                                    9.35                   32
# 106                                   10.05                   35
# 107                                    7.74                   33
# 108                                    7.46                   36
# 109                                    9.81                   28
# 110                                   16.55                   26
# 111                                    6.56                   32
# 112                                   15.34                   24
# 113                                    7.71                   24
# 114                                   11.85                   28
# 115                                    7.02                   35
# 116                                    6.46                   30
# 117                                   10.29                   24
# 118                                    6.25                   31
# 119                                    6.77                   29
# 120                                    8.95                   27
# 121                                    2.66                   36
# 122                                    8.80                   30
# 123                                   18.36                   21
# 124                                   15.27                   17
#
#      TARTargets (TAR)  CTCH%Catch Percentage (CTCH%)  \
# 0                 170                          66.47
# 1                 163                          70.55
# 2                 138                          62.32
# 3                 137                          63.50
# 4                 147                          85.03
# 5                 169                          65.68
# 6                 166                          66.87
# 7                 136                          64.71
# 8                 153                          73.86
# 9                 150                          68.67
# 10                168                          61.90
# 11                120                          63.33
# 12                130                          66.15
# 13                117                          68.38
# 14                136                          71.32
# 15                156                          74.36
# 16                119                          58.82
# 17                124                          62.10
# 18                108                          70.37
# 19                149                          68.46
# 20                107                          70.09
# 21                149                          54.36
# 22                 70                          81.43
# 23                101                          67.33
# 24                112                          58.04
# 25                107                          61.68
# 26                 98                          72.45
# 27                108                          68.52
# 28                 95                          62.11
# 29                 92                          70.65
# ..                ...                            ...
# 95                 44                          63.64
# 96                 54                          61.11
# 97                 52                          55.77
# 98                 46                          76.09
# 99                 44                          52.27
# 100                49                          59.18
# 101                61                          62.30
# 102                67                          37.31
# 103                76                          48.68
# 104                69                          49.28
# 105                52                          61.54
# 106                52                          67.31
# 107                44                          75.00
# 108                49                          73.47
# 109                45                          62.22
# 110                47                          55.32
# 111                49                          65.31
# 112                47                          51.06
# 113                43                          55.81
# 114                47                          59.57
# 115                53                          66.04
# 116                49                          61.22
# 117                46                          52.17
# 118                48                          64.58
# 119                43                          67.44
# 120                46                          58.70
# 121                44                          81.82
# 122                46                          65.22
# 123                58                          36.21
# 124                46                          36.96
#
#      YDSReceiving Yards (YDS)  TDReceiving Touchdowns (TD)  \
# 0                        1677                            8
# 1                        1572                           11
# 2                        1524                            8
# 3                        1479                           12
# 4                        1405                            9
# 5                        1386                           13
# 6                        1383                            7
# 7                        1377                            5
# 8                        1373                            9
# 9                        1336                           10
# 10                       1297                           15
# 11                       1270                            6
# 12                       1219                            6
# 13                       1204                            5
# 14                       1196                            6
# 15                       1163                            8
# 16                       1063                            5
# 17                       1052                            6
# 18                       1028                            7
# 19                       1021                            9
# 20                       1005                            7
# 21                        976                            4
# 22                        965                           10
# 23                        896                            6
# 24                        891                            4
# 25                        872                            4
# 26                        866                            4
# 27                        850                            6
# 28                        842                            7
# 29                        840                            6
# ..                        ...                          ...
# 95                        427                            5
# 96                        423                            7
# 97                        402                            5
# 98                        400                            2
# 99                        395                            4
# 100                       388                            2
# 101                       383                            2
# 102                       380                            1
# 103                       371                            1
# 104                       343                            1
# 105                       334                            5
# 106                       334                            1
# 107                       334                            4
# 108                       333                            2
# 109                       333                            2
# 110                       316                            2
# 111                       313                            3
# 112                       306                            1
# 113                       305                            0
# 114                       304                            0
# 115                       302                            1
# 116                       289                            6
# 117                       286                            1
# 118                       281                            2
# 119                       269                            3
# 120                       268                            2
# 121                       253                            1
# 122                       243                            2
# 123                       210                            7
# 124                       171                            1
#
#      YAC/RYAC/Reception (YAC/R)  xYAC/RExpected YAC/Reception (EYAC/R)  \
# 0                           4.2                                    4.0
# 1                           3.7                                    4.2
# 2                           3.8                                    3.4
# 3                           6.4                                    5.2
# 4                           4.1                                    3.5
# 5                           4.6                                    5.1
# 6                           6.1                                    5.8
# 7                          10.2                                    7.0
# 8                           3.9                                    3.8
# 9                           5.8                                    4.9
# 10                          5.0                                    4.8
# 11                          6.2                                    5.9
# 12                          5.3                                    5.5
# 13                          4.5                                    4.8
# 14                          4.4                                    5.2
# 15                          3.3                                    4.2
# 16                          5.4                                    5.1
# 17                          4.5                                    4.8
# 18                          5.8                                    5.4
# 19                          4.3                                    4.4
# 20                          5.7                                    3.8
# 21                          3.8                                    4.9
# 22                          4.2                                    5.3
# 23                          5.7                                    5.9
# 24                          4.3                                    4.5
# 25                          5.1                                    4.7
# 26                          4.6                                    5.2
# 27                          5.0                                    5.1
# 28                          4.6                                    3.9
# 29                          4.7                                    4.2
# ..                          ...                                    ...
# 95                          4.2                                    3.5
# 96                          5.4                                    4.9
# 97                          4.8                                    5.2
# 98                          3.0                                    4.2
# 99                          5.9                                    3.9
# 100                         7.6                                    6.7
# 101                         6.5                                    6.3
# 102                         2.8                                    2.9
# 103                         3.7                                    3.3
# 104                         3.0                                    3.4
# 105                         4.3                                    4.8
# 106                         2.7                                    3.2
# 107                         5.7                                    5.5
# 108                         4.4                                    5.1
# 109                         4.5                                    3.9
# 110                         3.4                                    3.2
# 111                         4.5                                    5.0
# 112                         4.5                                    5.5
# 113                         6.8                                    6.5
# 114                         3.4                                    5.5
# 115                         3.4                                    3.4
# 116                         2.1                                    2.8
# 117                         4.7                                    5.3
# 118                         5.0                                    5.5
# 119                         5.2                                    5.3
# 120                         3.1                                    4.0
# 121                         4.1                                    5.3
# 122                         2.4                                    3.6
# 123                         3.1                                    3.6
# 124                         0.9                                    1.3
#
#      +/-Avg YAC Above Expectation
# 0                             0.2
# 1                            -0.5
# 2                             0.3
# 3                             1.2
# 4                             0.5
# 5                            -0.4
# 6                             0.3
# 7                             3.2
# 8                             0.1
# 9                             0.9
# 10                            0.3
# 11                            0.3
# 12                           -0.3
# 13                           -0.3
# 14                           -0.8
# 15                           -0.9
# 16                            0.3
# 17                           -0.3
# 18                            0.4
# 19                           -0.1
# 20                            2.0
# 21                           -1.0
# 22                           -1.1
# 23                           -0.2
# 24                           -0.1
# 25                            0.4
# 26                           -0.6
# 27                           -0.1
# 28                            0.7
# 29                            0.5
# ..                            ...
# 95                            0.7
# 96                            0.5
# 97                           -0.5
# 98                           -1.1
# 99                            2.0
# 100                           1.0
# 101                           0.2
# 102                          -0.1
# 103                           0.4
# 104                          -0.4
# 105                          -0.5
# 106                          -0.5
# 107                           0.1
# 108                          -0.6
# 109                           0.6
# 110                           0.2
# 111                          -0.5
# 112                          -1.0
# 113                           0.2
# 114                          -2.2
# 115                           0.0
# 116                          -0.7
# 117                          -0.6
# 118                          -0.5
# 119                           0.0
# 120                          -0.9
# 121                          -1.2
# 122                          -1.2
# 123                          -0.5
# 124                          -0.4
#
# [125 rows x 15 columns]

# %%
rushingURL = 'https://nextgenstats.nfl.com/stats/rushing#yards'
browser.visit(rushingURL)
html = browser.html
soup = bs(html, 'html.parser')

# %%
rushingtable=pd.read_html(str(soup.find_all('table')))
rushdf= pd.DataFrame(rushingtable[1])
rushcolumnlist = rushingtable[0].values.tolist()[0]
rushcolumnlist.pop()
rushdf.columns = rushcolumnlist
# Out:
#             PLAYER NAME TEAM  EFFEfficiency (EFF)  \
# 0       Ezekiel Elliott  DAL                 3.67
# 1        Saquon Barkley  NYG                 3.63
# 2           Todd Gurley  LAR                 3.65
# 3             Joe Mixon  CIN                 3.55
# 4          Chris Carson  SEA                 3.66
# 5   Christian McCaffrey  CAR                 3.44
# 6         Derrick Henry  TEN                 3.73
# 7       Adrian Peterson  WAS                 4.31
# 8       Phillip Lindsay  DEN                 3.39
# 9            Nick Chubb  CLE                 3.48
# 10         James Conner  PIT                 3.64
# 11         Lamar Miller  HOU                 3.50
# 12        David Johnson  ARI                 4.00
# 13        Jordan Howard  CHI                 3.73
# 14          Sony Michel   NE                 3.71
# 15          Marlon Mack  IND                 3.50
# 16        Melvin Gordon  LAC                 3.62
# 17         Alvin Kamara   NO                 3.96
# 18        Peyton Barber   TB                 4.04
# 19          Kareem Hunt   KC                 3.89
# 20          Matt Breida   SF                 4.00
# 21        Tevin Coleman  ATL                 4.23
# 22          Aaron Jones   GB                 3.45
# 23          Doug Martin  OAK                 3.78
# 24           Frank Gore  MIA                 3.13
# 25          Gus Edwards  BAL                 2.78
# 26       Isaiah Crowell  NYJ                 3.65
# 27          Mark Ingram   NO                 3.51
# 28      Kerryon Johnson  DET                 3.42
# 29          Dalvin Cook  MIN                 3.97
# 30      Latavius Murray  MIN                 3.76
# 31          Carlos Hyde  JAX                 4.79
# 32        Austin Ekeler  LAC                 3.96
# 33         Kenyan Drake  MIA                 4.07
# 34           Mike Davis  SEA                 3.49
# 35        Royce Freeman  DEN                 4.27
# 36           Dion Lewis  TEN                 4.59
# 37         LeSean McCoy  BUF                 5.07
# 38           Josh Adams  PHI                 4.09
# 39          Alfred Blue  HOU                 4.39
# 40      Jamaal Williams   GB                 4.09
# 41          Tarik Cohen  CHI                 4.96
# 42    Leonard Fournette  JAX                 4.44
# 43        Alfred Morris   SF                 4.27
# 44          James White   NE                 3.56
# 45        Rashaad Penny  SEA                 3.87
# 46    LeGarrette Blount  DET                 5.10
# 47          T.J. Yeldon  JAX                 3.83
# 48         Alex Collins  BAL                 4.91
# 49          Chris Ivory  BUF                 4.60
# 50       Marshawn Lynch  OAK                 4.11
# 51    Wendell Smallwood  PHI                 3.97
# 52            Ito Smith  ATL                 4.69
# 53         Nyheim Hines  IND                 4.19
# 54       Elijah McGuire  NYJ                 5.20
#
#     8+D%8+ Defenders in the Box (8+D%)  \
# 0                                24.67
# 1                                22.99
# 2                                 8.20
# 3                                16.03
# 4                                21.86
# 5                                19.63
# 6                                32.09
# 7                                16.73
# 8                                14.06
# 9                                34.38
# 10                               27.91
# 11                               23.33
# 12                               24.03
# 13                               14.00
# 14                               26.79
# 15                               23.08
# 16                               25.71
# 17                               22.16
# 18                               22.65
# 19                               15.47
# 20                               25.49
# 21                               25.75
# 22                               13.53
# 23                               20.93
# 24                               12.18
# 25                               13.14
# 26                               26.57
# 27                               31.88
# 28                               21.19
# 29                               18.05
# 30                               27.86
# 31                               34.30
# 32                               28.30
# 33                               10.00
# 34                               11.61
# 35                               36.15
# 36                               25.81
# 37                               16.15
# 38                               16.67
# 39                               22.67
# 40                               11.57
# 41                                5.05
# 42                               35.34
# 43                               34.23
# 44                               11.70
# 45                               10.59
# 46                               38.96
# 47                               21.15
# 48                               34.21
# 49                               20.87
# 50                               22.22
# 51                                6.90
# 52                               21.11
# 53                               11.76
# 54                               25.00
#
#     TLOSAvg Time Behind Line Of Scrimmage (TLOS)  ATTRushing Attempts (ATT)  \
# 0                                           2.88                        304
# 1                                           2.94                        261
# 2                                           2.80                        256
# 3                                           2.83                        237
# 4                                           2.86                        247
# 5                                           2.75                        219
# 6                                           2.93                        215
# 7                                           2.97                        251
# 8                                           2.64                        192
# 9                                           3.01                        192
# 10                                          2.89                        215
# 11                                          2.76                        210
# 12                                          2.68                        258
# 13                                          2.55                        250
# 14                                          2.69                        209
# 15                                          2.80                        195
# 16                                          2.83                        175
# 17                                          2.66                        194
# 18                                          2.78                        234
# 19                                          2.76                        181
# 20                                          2.89                        153
# 21                                          2.92                        167
# 22                                          2.70                        133
# 23                                          2.73                        172
# 24                                          2.53                        156
# 25                                          2.43                        137
# 26                                          2.94                        143
# 27                                          2.58                        138
# 28                                          2.96                        118
# 29                                          2.91                        133
# 30                                          2.82                        140
# 31                                          3.02                        172
# 32                                          2.92                        106
# 33                                          2.78                        120
# 34                                          2.65                        112
# 35                                          2.92                        130
# 36                                          2.86                        155
# 37                                          2.98                        161
# 38                                          2.93                        120
# 39                                          2.73                        150
# 40                                          2.71                        121
# 41                                          3.34                         99
# 42                                          2.63                        133
# 43                                          2.78                        111
# 44                                          2.67                         94
# 45                                          3.01                         85
# 46                                          2.81                        154
# 47                                          2.72                        104
# 48                                          3.01                        114
# 49                                          2.86                        115
# 50                                          2.85                         90
# 51                                          2.75                         87
# 52                                          2.87                         90
# 53                                          2.78                         85
# 54                                          2.95                         92
#
#     YDSRushing Yards (YDS)  AVGAverage Rush Yards (AVG)  \
# 0                     1434                          4.7
# 1                     1307                          5.0
# 2                     1251                          4.9
# 3                     1168                          4.9
# 4                     1151                          4.7
# 5                     1098                          5.0
# 6                     1059                          4.9
# 7                     1042                          4.2
# 8                     1042                          5.4
# 9                      996                          5.2
# 10                     973                          4.5
# 11                     973                          4.6
# 12                     940                          3.6
# 13                     935                          3.7
# 14                     931                          4.5
# 15                     908                          4.7
# 16                     885                          5.1
# 17                     883                          4.6
# 18                     871                          3.7
# 19                     824                          4.6
# 20                     814                          5.3
# 21                     800                          4.8
# 22                     728                          5.5
# 23                     723                          4.2
# 24                     722                          4.6
# 25                     718                          5.2
# 26                     685                          4.8
# 27                     645                          4.7
# 28                     641                          5.4
# 29                     615                          4.6
# 30                     578                          4.1
# 31                     571                          3.3
# 32                     554                          5.2
# 33                     535                          4.5
# 34                     524                          4.7
# 35                     521                          4.0
# 36                     517                          3.3
# 37                     514                          3.2
# 38                     511                          4.3
# 39                     499                          3.3
# 40                     464                          3.8
# 41                     444                          4.5
# 42                     439                          3.3
# 43                     428                          3.9
# 44                     425                          4.5
# 45                     419                          4.9
# 46                     418                          2.7
# 47                     414                          4.0
# 48                     411                          3.6
# 49                     385                          3.3
# 50                     376                          4.2
# 51                     364                          4.2
# 52                     315                          3.5
# 53                     314                          3.7
# 54                     276                          3.0
#
#     TDRushing Touchdowns (TD)
# 0                           6
# 1                          11
# 2                          17
# 3                           8
# 4                           9
# 5                           7
# 6                          12
# 7                           7
# 8                           9
# 9                           8
# 10                         12
# 11                          5
# 12                          7
# 13                          9
# 14                          6
# 15                          9
# 16                         10
# 17                         14
# 18                          5
# 19                          7
# 20                          3
# 21                          4
# 22                          8
# 23                          4
# 24                          0
# 25                          2
# 26                          6
# 27                          6
# 28                          3
# 29                          2
# 30                          6
# 31                          5
# 32                          3
# 33                          4
# 34                          4
# 35                          5
# 36                          1
# 37                          3
# 38                          3
# 39                          2
# 40                          3
# 41                          3
# 42                          5
# 43                          2
# 44                          5
# 45                          2
# 46                          5
# 47                          1
# 48                          7
# 49                          1
# 50                          3
# 51                          3
# 52                          4
# 53                          2
# 54                          3

# %%
passingURL = 'https://nextgenstats.nfl.com/stats/passing#yards'
browser.visit(passingURL)
html = browser.html
soup = bs(html, 'html.parser')

# %%
passingtable=pd.read_html(str(soup.find_all('table')))
passdf= pd.DataFrame(passingtable[1])
passcolumnlist = passingtable[0].values.tolist()[0]
passcolumnlist.pop()
passdf.columns = passcolumnlist
# Out:
#            PLAYER NAME TEAM  TTTime To Throw (TT)  \
# 0   Ben Roethlisberger  PIT                  2.55
# 1      Patrick Mahomes   KC                  2.91
# 2            Matt Ryan  ATL                  2.68
# 3           Jared Goff  LAR                  2.94
# 4          Andrew Luck  IND                  2.63
# 5        Aaron Rodgers   GB                  2.95
# 6            Tom Brady   NE                  2.61
# 7        Philip Rivers  LAC                  2.62
# 8          Eli Manning  NYG                  2.65
# 9         Kirk Cousins  MIN                  2.74
# 10      Deshaun Watson  HOU                  3.01
# 11          Derek Carr  OAK                  2.55
# 12          Drew Brees   NO                  2.59
# 13         Case Keenum  DEN                  2.68
# 14        Dak Prescott  DAL                  2.82
# 15    Matthew Stafford  DET                  2.63
# 16      Baker Mayfield  CLE                  2.79
# 17      Russell Wilson  SEA                  3.01
# 18          Cam Newton  CAR                  2.69
# 19   Mitchell Trubisky  CHI                  2.65
# 20        Carson Wentz  PHI                  2.66
# 21      Jameis Winston   TB                  2.80
# 22         Sam Darnold  NYJ                  2.91
# 23       Blake Bortles  JAX                  2.76
# 24         Andy Dalton  CIN                  2.61
# 25      Marcus Mariota  TEN                  2.68
# 26          Joe Flacco  BAL                  2.71
# 27    Ryan Fitzpatrick   TB                  2.64
# 28          Josh Rosen  ARI                  2.77
# 29        Nick Mullens   SF                  2.70
# 30          Alex Smith  WAS                  2.78
# 31          Josh Allen  BUF                  3.22
# 32      Ryan Tannehill  MIA                  2.65
# 33          Nick Foles  PHI                  2.68
# 34       C.J. Beathard   SF                  2.61
# 35      Brock Osweiler  MIA                  2.78
# 36       Lamar Jackson  BAL                  3.10
# 37        Jeff Driskel  CIN                  2.56
# 38        Cody Kessler  JAX                  2.92
#
#     CAYAverage Completed Air Yards (CAY)  IAYAverage Intended Air Yards (IAY)  \
# 0                                    4.8                                  7.7
# 1                                    6.4                                  9.2
# 2                                    6.5                                  8.5
# 3                                    7.0                                  8.8
# 4                                    6.1                                  7.6
# 5                                    6.0                                  8.8
# 6                                    5.6                                  7.6
# 7                                    6.3                                  7.9
# 8                                    5.3                                  7.2
# 9                                    5.6                                  7.4
# 10                                   6.8                                  8.8
# 11                                   4.9                                  6.7
# 12                                   5.9                                  7.1
# 13                                   5.6                                  7.5
# 14                                   5.5                                  7.6
# 15                                   4.7                                  7.0
# 16                                   6.3                                  9.1
# 17                                   7.3                                  9.2
# 18                                   5.0                                  7.1
# 19                                   6.0                                  8.8
# 20                                   5.8                                  7.8
# 21                                   8.4                                 10.8
# 22                                   6.5                                  9.3
# 23                                   4.9                                  7.0
# 24                                   6.2                                  8.3
# 25                                   5.3                                  7.5
# 26                                   5.9                                  8.4
# 27                                   8.8                                 10.2
# 28                                   5.9                                  8.4
# 29                                   5.8                                  7.4
# 30                                   5.7                                  8.1
# 31                                   6.5                                 11.0
# 32                                   4.9                                  7.9
# 33                                   4.6                                  6.7
# 34                                   5.0                                  6.8
# 35                                   4.8                                  7.7
# 36                                   6.5                                  8.4
# 37                                   4.6                                  7.8
# 38                                   4.2                                  6.7
#
#     AYDAverage Air Yards Differential (AYD)  AGG%Aggressiveness (AGG%)  \
# 0                                      -2.9                       16.7
# 1                                      -2.8                       12.2
# 2                                      -2.0                       16.8
# 3                                      -1.8                       13.2
# 4                                      -1.5                       18.2
# 5                                      -2.8                       13.7
# 6                                      -2.0                       13.9
# 7                                      -1.6                       15.7
# 8                                      -1.9                       18.8
# 9                                      -1.9                       13.0
# 10                                     -2.0                       14.5
# 11                                     -1.8                       13.2
# 12                                     -1.2                       15.5
# 13                                     -1.9                       16.0
# 14                                     -2.1                       17.7
# 15                                     -2.3                       15.9
# 16                                     -2.8                       15.6
# 17                                     -1.9                       13.8
# 18                                     -2.1                       17.2
# 19                                     -2.7                       17.7
# 20                                     -2.0                       16.2
# 21                                     -2.4                       20.4
# 22                                     -2.8                       19.6
# 23                                     -2.1                       16.9
# 24                                     -2.2                       17.0
# 25                                     -2.2                       12.7
# 26                                     -2.5                       17.2
# 27                                     -1.4                       20.7
# 28                                     -2.5                       21.6
# 29                                     -1.6                       12.0
# 30                                     -2.4                       17.7
# 31                                     -4.6                       13.8
# 32                                     -3.0                       13.1
# 33                                     -2.0                       14.9
# 34                                     -1.8                       14.8
# 35                                     -2.9                        8.4
# 36                                     -1.9                       17.6
# 37                                     -3.1                       21.0
# 38                                     -2.5                       12.2
#
#     LCADLongest Completed Air Distance (LCAD)  \
# 0                                        52.9
# 1                                        60.7
# 2                                        54.9
# 3                                        62.7
# 4                                        51.7
# 5                                        61.4
# 6                                        49.9
# 7                                        55.3
# 8                                        55.4
# 9                                        62.9
# 10                                       61.3
# 11                                       49.7
# 12                                       45.5
# 13                                       55.3
# 14                                       48.2
# 15                                       53.4
# 16                                       63.8
# 17                                       54.4
# 18                                       40.5
# 19                                       60.7
# 20                                       55.0
# 21                                       54.8
# 22                                       54.1
# 23                                       46.8
# 24                                       47.5
# 25                                       51.1
# 26                                       50.6
# 27                                       53.7
# 28                                       58.6
# 29                                       37.8
# 30                                       48.9
# 31                                       63.9
# 32                                       55.3
# 33                                       55.6
# 34                                       48.6
# 35                                       45.8
# 36                                       35.8
# 37                                       44.9
# 38                                       44.6
#
#     AYTSAir Yards to the Sticks (AYTS)  ATTPassing Attempts (ATT)  \
# 0                                 -0.9                        675
# 1                                  0.2                        580
# 2                                 -0.5                        608
# 3                                  0.1                        561
# 4                                 -1.2                        639
# 5                                 -0.2                        597
# 6                                 -1.1                        570
# 7                                 -1.1                        508
# 8                                 -2.0                        576
# 9                                 -1.2                        606
# 10                                -0.2                        505
# 11                                -2.0                        553
# 12                                -1.6                        489
# 13                                -1.5                        586
# 14                                -1.5                        526
# 15                                -2.0                        555
# 16                                 0.1                        486
# 17                                 0.0                        427
# 18                                -1.7                        471
# 19                                 0.1                        434
# 20                                -1.1                        401
# 21                                 1.5                        378
# 22                                 0.1                        414
# 23                                -1.6                        403
# 24                                -0.7                        365
# 25                                -1.3                        331
# 26                                -0.3                        379
# 27                                 1.2                        246
# 28                                -1.0                        393
# 29                                -1.4                        274
# 30                                -0.9                        328
# 31                                 1.4                        320
# 32                                -1.5                        274
# 33                                -2.5                        195
# 34                                -2.3                        169
# 35                                -0.4                        178
# 36                                -0.4                        170
# 37                                -1.8                        176
# 38                                -2.7                        131
#
#     YDSPassing Yards (YDS)  TDPassing Touchdowns (TD)  INTInterceptions (INT)  \
# 0                     5130                         34                      16
# 1                     5097                         50                      12
# 2                     4924                         35                       8
# 3                     4688                         32                      12
# 4                     4593                         39                      15
# 5                     4442                         25                       2
# 6                     4355                         29                      11
# 7                     4308                         32                      12
# 8                     4299                         21                      11
# 9                     4298                         30                      10
# 10                    4165                         26                       9
# 11                    4049                         19                      10
# 12                    3992                         32                       5
# 13                    3890                         18                      15
# 14                    3885                         22                       8
# 15                    3777                         21                      11
# 16                    3725                         27                      14
# 17                    3448                         35                       7
# 18                    3395                         24                      13
# 19                    3223                         24                      12
# 20                    3074                         21                       7
# 21                    2992                         19                      14
# 22                    2865                         17                      15
# 23                    2718                         13                      11
# 24                    2566                         21                      11
# 25                    2528                         11                       8
# 26                    2465                         12                       6
# 27                    2366                         17                      12
# 28                    2278                         11                      14
# 29                    2277                         13                      10
# 30                    2180                         10                       5
# 31                    2074                         10                      12
# 32                    1979                         17                       9
# 33                    1413                          7                       4
# 34                    1252                          8                       7
# 35                    1247                          6                       4
# 36                    1201                          6                       3
# 37                    1003                          6                       2
# 38                     709                          2                       2
#
#     RATEPasser Rating (RATE)  COMP%Completion Percentage (COMP%)  \
# 0                       96.5                                67.0
# 1                      113.8                                66.0
# 2                      107.4                                69.4
# 3                      101.1                                64.9
# 4                       98.7                                67.3
# 5                       97.6                                62.3
# 6                       97.7                                65.8
# 7                      105.5                                68.3
# 8                       92.4                                66.0
# 9                       99.7                                70.1
# 10                     103.1                                68.3
# 11                      93.9                                68.9
# 12                     115.7                                74.4
# 13                      81.2                                62.3
# 14                      96.9                                67.7
# 15                      89.9                                66.1
# 16                      93.7                                63.8
# 17                     110.9                                65.6
# 18                      94.2                                67.9
# 19                      95.4                                66.6
# 20                     102.2                                69.6
# 21                      90.2                                64.6
# 22                      77.6                                57.7
# 23                      79.8                                60.3
# 24                      89.6                                61.9
# 25                      92.3                                68.9
# 26                      84.2                                61.2
# 27                     100.4                                66.7
# 28                      66.7                                55.2
# 29                      90.8                                64.2
# 30                      85.7                                62.5
# 31                      67.9                                52.8
# 32                      92.7                                64.2
# 33                      96.0                                72.3
# 34                      81.8                                60.4
# 35                      86.0                                63.5
# 36                      84.5                                58.2
# 37                      82.2                                59.7
# 38                      77.4                                64.9
#
#     xCOMP%Expected Completion Percentage  \
# 0                                   66.9
# 1                                   64.3
# 2                                   64.8
# 3                                   63.9
# 4                                   66.6
# 5                                   62.9
# 6                                   67.7
# 7                                   66.2
# 8                                   67.4
# 9                                   64.8
# 10                                  64.4
# 11                                  68.0
# 12                                  67.0
# 13                                  63.5
# 14                                  65.6
# 15                                  65.7
# 16                                  64.2
# 17                                  60.4
# 18                                  64.8
# 19                                  65.2
# 20                                  66.4
# 21                                  62.7
# 22                                  59.8
# 23                                  67.2
# 24                                  62.4
# 25                                  67.9
# 26                                  64.1
# 27                                  62.7
# 28                                  59.4
# 29                                  64.7
# 30                                  62.5
# 31                                  59.6
# 32                                  65.1
# 33                                  66.6
# 34                                  68.1
# 35                                  64.8
# 36                                  62.7
# 37                                  62.7
# 38                                  62.6
#
#     +/-Completion Percentage Above Expectation
# 0                                          0.1
# 1                                          1.7
# 2                                          4.6
# 3                                          1.0
# 4                                          0.7
# 5                                         -0.6
# 6                                         -1.9
# 7                                          2.1
# 8                                         -1.4
# 9                                          5.3
# 10                                         3.9
# 11                                         0.9
# 12                                         7.4
# 13                                        -1.2
# 14                                         2.1
# 15                                         0.4
# 16                                        -0.5
# 17                                         5.2
# 18                                         3.1
# 19                                         1.4
# 20                                         3.2
# 21                                         1.9
# 22                                        -2.1
# 23                                        -6.9
# 24                                        -0.5
# 25                                         1.0
# 26                                        -2.9
# 27                                         3.9
# 28                                        -4.2
# 29                                        -0.5
# 30                                         0.0
# 31                                        -6.8
# 32                                        -0.9
# 33                                         5.7
# 34                                        -7.8
# 35                                        -1.3
# 36                                        -4.5
# 37                                        -3.0
# 38                                         2.3

# %%
for i in reccolumnlist:
    i.replace('.YAC','YAC')
recdf_json = recdf.to_dict(orient = 'records')
recdf_json
# Out:
# [{'PLAYER NAME': 'Julio Jones',
#   'TEAM': 'ATL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 2.5,
#   'TAYAverage Targeted Air Yards (TAY)': 14.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 45.64,
#   'RECReceptions (REC)': 113,
#   'TARTargets (TAR)': 170,
#   'CTCH%Catch Percentage (CTCH%)': 66.47,
#   'YDSReceiving Yards (YDS)': 1677,
#   'TDReceiving Touchdowns (TD)': 8,
#   'YAC/RYAC/Reception (YAC/R)': 4.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.0,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'DeAndre Hopkins',
#   'TEAM': 'HOU',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.9,
#   'SEPAverage Separation (SEP)': 2.5,
#   'TAYAverage Targeted Air Yards (TAY)': 11.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 44.04,
#   'RECReceptions (REC)': 115,
#   'TARTargets (TAR)': 163,
#   'CTCH%Catch Percentage (CTCH%)': 70.55,
#   'YDSReceiving Yards (YDS)': 1572,
#   'TDReceiving Touchdowns (TD)': 11,
#   'YAC/RYAC/Reception (YAC/R)': 3.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Mike Evans',
#   'TEAM': 'TB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 2.1,
#   'TAYAverage Targeted Air Yards (TAY)': 15.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 32.83,
#   'RECReceptions (REC)': 86,
#   'TARTargets (TAR)': 138,
#   'CTCH%Catch Percentage (CTCH%)': 62.32,
#   'YDSReceiving Yards (YDS)': 1524,
#   'TDReceiving Touchdowns (TD)': 8,
#   'YAC/RYAC/Reception (YAC/R)': 3.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.4,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Tyreek Hill',
#   'TEAM': 'KC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 14.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 38.19,
#   'RECReceptions (REC)': 87,
#   'TARTargets (TAR)': 137,
#   'CTCH%Catch Percentage (CTCH%)': 63.5,
#   'YDSReceiving Yards (YDS)': 1479,
#   'TDReceiving Touchdowns (TD)': 12,
#   'YAC/RYAC/Reception (YAC/R)': 6.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.2,
#   '+/-Avg .YAC Above Expectation': 1.2},
#  {'PLAYER NAME': 'Michael Thomas',
#   'TEAM': 'NO',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.6,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 7.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 30.26,
#   'RECReceptions (REC)': 125,
#   'TARTargets (TAR)': 147,
#   'CTCH%Catch Percentage (CTCH%)': 85.03,
#   'YDSReceiving Yards (YDS)': 1405,
#   'TDReceiving Touchdowns (TD)': 9,
#   'YAC/RYAC/Reception (YAC/R)': 4.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.5,
#   '+/-Avg .YAC Above Expectation': 0.5},
#  {'PLAYER NAME': 'Davante Adams',
#   'TEAM': 'GB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.8,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 33.97,
#   'RECReceptions (REC)': 111,
#   'TARTargets (TAR)': 169,
#   'CTCH%Catch Percentage (CTCH%)': 65.68,
#   'YDSReceiving Yards (YDS)': 1386,
#   'TDReceiving Touchdowns (TD)': 13,
#   'YAC/RYAC/Reception (YAC/R)': 4.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.1,
#   '+/-Avg .YAC Above Expectation': -0.4},
#  {'PLAYER NAME': 'JuJu Smith-Schuster',
#   'TEAM': 'PIT',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.3,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 8.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 27.73,
#   'RECReceptions (REC)': 111,
#   'TARTargets (TAR)': 166,
#   'CTCH%Catch Percentage (CTCH%)': 66.87,
#   'YDSReceiving Yards (YDS)': 1383,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 6.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.8,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'George Kittle',
#   'TEAM': 'SF',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 7.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 25.32,
#   'RECReceptions (REC)': 88,
#   'TARTargets (TAR)': 136,
#   'CTCH%Catch Percentage (CTCH%)': 64.71,
#   'YDSReceiving Yards (YDS)': 1377,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 10.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 7.0,
#   '+/-Avg .YAC Above Expectation': 3.2},
#  {'PLAYER NAME': 'Adam Thielen',
#   'TEAM': 'MIN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 32.77,
#   'RECReceptions (REC)': 113,
#   'TARTargets (TAR)': 153,
#   'CTCH%Catch Percentage (CTCH%)': 73.86,
#   'YDSReceiving Yards (YDS)': 1373,
#   'TDReceiving Touchdowns (TD)': 9,
#   'YAC/RYAC/Reception (YAC/R)': 3.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.8,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Travis Kelce',
#   'TEAM': 'KC',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 8.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 25.12,
#   'RECReceptions (REC)': 103,
#   'TARTargets (TAR)': 150,
#   'CTCH%Catch Percentage (CTCH%)': 68.67,
#   'YDSReceiving Yards (YDS)': 1336,
#   'TDReceiving Touchdowns (TD)': 10,
#   'YAC/RYAC/Reception (YAC/R)': 5.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.9,
#   '+/-Avg .YAC Above Expectation': 0.9},
#  {'PLAYER NAME': 'Antonio Brown',
#   'TEAM': 'PIT',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.0,
#   'SEPAverage Separation (SEP)': 2.6,
#   'TAYAverage Targeted Air Yards (TAY)': 11.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 36.01,
#   'RECReceptions (REC)': 104,
#   'TARTargets (TAR)': 168,
#   'CTCH%Catch Percentage (CTCH%)': 61.9,
#   'YDSReceiving Yards (YDS)': 1297,
#   'TDReceiving Touchdowns (TD)': 15,
#   'YAC/RYAC/Reception (YAC/R)': 5.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'T.Y. Hilton',
#   'TEAM': 'IND',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 2.3,
#   'TAYAverage Targeted Air Yards (TAY)': 11.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 27.57,
#   'RECReceptions (REC)': 76,
#   'TARTargets (TAR)': 120,
#   'CTCH%Catch Percentage (CTCH%)': 63.33,
#   'YDSReceiving Yards (YDS)': 1270,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 6.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.9,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Robert Woods',
#   'TEAM': 'LAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.4,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 29.84,
#   'RECReceptions (REC)': 86,
#   'TARTargets (TAR)': 130,
#   'CTCH%Catch Percentage (CTCH%)': 66.15,
#   'YDSReceiving Yards (YDS)': 1219,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 5.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Brandin Cooks',
#   'TEAM': 'LAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 12.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 30.8,
#   'RECReceptions (REC)': 80,
#   'TARTargets (TAR)': 117,
#   'CTCH%Catch Percentage (CTCH%)': 68.38,
#   'YDSReceiving Yards (YDS)': 1204,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Keenan Allen',
#   'TEAM': 'LAC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.3,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 8.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 29.75,
#   'RECReceptions (REC)': 97,
#   'TARTargets (TAR)': 136,
#   'CTCH%Catch Percentage (CTCH%)': 71.32,
#   'YDSReceiving Yards (YDS)': 1196,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 4.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.2,
#   '+/-Avg .YAC Above Expectation': -0.8},
#  {'PLAYER NAME': 'Zach Ertz',
#   'TEAM': 'PHI',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.1,
#   'SEPAverage Separation (SEP)': 3.2,
#   'TAYAverage Targeted Air Yards (TAY)': 7.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 25.85,
#   'RECReceptions (REC)': 116,
#   'TARTargets (TAR)': 156,
#   'CTCH%Catch Percentage (CTCH%)': 74.36,
#   'YDSReceiving Yards (YDS)': 1163,
#   'TDReceiving Touchdowns (TD)': 8,
#   'YAC/RYAC/Reception (YAC/R)': 3.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': -0.9},
#  {'PLAYER NAME': 'Kenny Golladay',
#   'TEAM': 'DET',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.9,
#   'SEPAverage Separation (SEP)': 2.3,
#   'TAYAverage Targeted Air Yards (TAY)': 12.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 37.34,
#   'RECReceptions (REC)': 70,
#   'TARTargets (TAR)': 119,
#   'CTCH%Catch Percentage (CTCH%)': 58.82,
#   'YDSReceiving Yards (YDS)': 1063,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 5.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.1,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Odell Beckham',
#   'TEAM': 'NYG',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 33.29,
#   'RECReceptions (REC)': 77,
#   'TARTargets (TAR)': 124,
#   'CTCH%Catch Percentage (CTCH%)': 62.1,
#   'YDSReceiving Yards (YDS)': 1052,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Tyler Boyd',
#   'TEAM': 'CIN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.95,
#   'RECReceptions (REC)': 76,
#   'TARTargets (TAR)': 108,
#   'CTCH%Catch Percentage (CTCH%)': 70.37,
#   'YDSReceiving Yards (YDS)': 1028,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 5.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.4,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'Stefon Diggs',
#   'TEAM': 'MIN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 8.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 29.56,
#   'RECReceptions (REC)': 102,
#   'TARTargets (TAR)': 149,
#   'CTCH%Catch Percentage (CTCH%)': 68.46,
#   'YDSReceiving Yards (YDS)': 1021,
#   'TDReceiving Touchdowns (TD)': 9,
#   'YAC/RYAC/Reception (YAC/R)': 4.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.4,
#   '+/-Avg .YAC Above Expectation': -0.1},
#  {'PLAYER NAME': 'Amari Cooper',
#   'TEAM': 'DAL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.0,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 28.97,
#   'RECReceptions (REC)': 75,
#   'TARTargets (TAR)': 107,
#   'CTCH%Catch Percentage (CTCH%)': 70.09,
#   'YDSReceiving Yards (YDS)': 1005,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 5.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.8,
#   '+/-Avg .YAC Above Expectation': 2.0},
#  {'PLAYER NAME': 'Jarvis Landry',
#   'TEAM': 'CLE',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 10.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 30.3,
#   'RECReceptions (REC)': 81,
#   'TARTargets (TAR)': 149,
#   'CTCH%Catch Percentage (CTCH%)': 54.36,
#   'YDSReceiving Yards (YDS)': 976,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 3.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.9,
#   '+/-Avg .YAC Above Expectation': -1.0},
#  {'PLAYER NAME': 'Tyler Lockett',
#   'TEAM': 'SEA',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.6,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 13.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 24.4,
#   'RECReceptions (REC)': 57,
#   'TARTargets (TAR)': 70,
#   'CTCH%Catch Percentage (CTCH%)': 81.43,
#   'YDSReceiving Yards (YDS)': 965,
#   'TDReceiving Touchdowns (TD)': 10,
#   'YAC/RYAC/Reception (YAC/R)': 4.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': -1.1},
#  {'PLAYER NAME': 'Jared Cook',
#   'TEAM': 'OAK',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 8.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.13,
#   'RECReceptions (REC)': 68,
#   'TARTargets (TAR)': 101,
#   'CTCH%Catch Percentage (CTCH%)': 67.33,
#   'YDSReceiving Yards (YDS)': 896,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 5.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.9,
#   '+/-Avg .YAC Above Expectation': -0.2},
#  {'PLAYER NAME': 'Corey Davis',
#   'TEAM': 'TEN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.1,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 10.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 35.88,
#   'RECReceptions (REC)': 65,
#   'TARTargets (TAR)': 112,
#   'CTCH%Catch Percentage (CTCH%)': 58.04,
#   'YDSReceiving Yards (YDS)': 891,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.5,
#   '+/-Avg .YAC Above Expectation': -0.1},
#  {'PLAYER NAME': 'Sterling Shepard',
#   'TEAM': 'NYG',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 10.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 25.98,
#   'RECReceptions (REC)': 66,
#   'TARTargets (TAR)': 107,
#   'CTCH%Catch Percentage (CTCH%)': 61.68,
#   'YDSReceiving Yards (YDS)': 872,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 5.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.7,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'Emmanuel Sanders',
#   'TEAM': 'DEN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 3.2,
#   'TAYAverage Targeted Air Yards (TAY)': 9.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 20.87,
#   'RECReceptions (REC)': 71,
#   'TARTargets (TAR)': 98,
#   'CTCH%Catch Percentage (CTCH%)': 72.45,
#   'YDSReceiving Yards (YDS)': 866,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.2,
#   '+/-Avg .YAC Above Expectation': -0.6},
#  {'PLAYER NAME': 'Julian Edelman',
#   'TEAM': 'NE',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 7.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 19.21,
#   'RECReceptions (REC)': 74,
#   'TARTargets (TAR)': 108,
#   'CTCH%Catch Percentage (CTCH%)': 68.52,
#   'YDSReceiving Yards (YDS)': 850,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 5.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.1,
#   '+/-Avg .YAC Above Expectation': -0.1},
#  {'PLAYER NAME': 'Chris Godwin',
#   'TEAM': 'TB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 2.6,
#   'TAYAverage Targeted Air Yards (TAY)': 11.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 17.14,
#   'RECReceptions (REC)': 59,
#   'TARTargets (TAR)': 95,
#   'CTCH%Catch Percentage (CTCH%)': 62.11,
#   'YDSReceiving Yards (YDS)': 842,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 4.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.9,
#   '+/-Avg .YAC Above Expectation': 0.7},
#  {'PLAYER NAME': 'Alshon Jeffery',
#   'TEAM': 'PHI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.5,
#   'SEPAverage Separation (SEP)': 2.5,
#   'TAYAverage Targeted Air Yards (TAY)': 10.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.67,
#   'RECReceptions (REC)': 65,
#   'TARTargets (TAR)': 92,
#   'CTCH%Catch Percentage (CTCH%)': 70.65,
#   'YDSReceiving Yards (YDS)': 840,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 4.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': 0.5},
#  {'PLAYER NAME': 'Mohamed Sanu',
#   'TEAM': 'ATL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 7.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 14.23,
#   'RECReceptions (REC)': 66,
#   'TARTargets (TAR)': 94,
#   'CTCH%Catch Percentage (CTCH%)': 70.21,
#   'YDSReceiving Yards (YDS)': 838,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 6.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.6,
#   '+/-Avg .YAC Above Expectation': 0.5},
#  {'PLAYER NAME': 'Calvin Ridley',
#   'TEAM': 'ATL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 3.2,
#   'TAYAverage Targeted Air Yards (TAY)': 10.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 17.68,
#   'RECReceptions (REC)': 64,
#   'TARTargets (TAR)': 92,
#   'CTCH%Catch Percentage (CTCH%)': 69.57,
#   'YDSReceiving Yards (YDS)': 821,
#   'TDReceiving Touchdowns (TD)': 10,
#   'YAC/RYAC/Reception (YAC/R)': 5.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.9,
#   '+/-Avg .YAC Above Expectation': 0.9},
#  {'PLAYER NAME': 'Adam Humphries',
#   'TEAM': 'TB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.5,
#   'SEPAverage Separation (SEP)': 3.6,
#   'TAYAverage Targeted Air Yards (TAY)': 6.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 9.66,
#   'RECReceptions (REC)': 76,
#   'TARTargets (TAR)': 105,
#   'CTCH%Catch Percentage (CTCH%)': 72.38,
#   'YDSReceiving Yards (YDS)': 816,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 5.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'Golden Tate',
#   'TEAM': 'PHI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 6.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 17.66,
#   'RECReceptions (REC)': 74,
#   'TARTargets (TAR)': 113,
#   'CTCH%Catch Percentage (CTCH%)': 65.49,
#   'YDSReceiving Yards (YDS)': 789,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 5.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.0,
#   '+/-Avg .YAC Above Expectation': 0.8},
#  {'PLAYER NAME': 'D.J. Moore',
#   'TEAM': 'CAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.1,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 17.89,
#   'RECReceptions (REC)': 55,
#   'TARTargets (TAR)': 82,
#   'CTCH%Catch Percentage (CTCH%)': 67.07,
#   'YDSReceiving Yards (YDS)': 788,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 7.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.9,
#   '+/-Avg .YAC Above Expectation': 3.0},
#  {'PLAYER NAME': 'DeSean Jackson',
#   'TEAM': 'TB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 7.3,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 19.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 21.41,
#   'RECReceptions (REC)': 41,
#   'TARTargets (TAR)': 74,
#   'CTCH%Catch Percentage (CTCH%)': 55.41,
#   'YDSReceiving Yards (YDS)': 774,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.7,
#   '+/-Avg .YAC Above Expectation': -0.1},
#  {'PLAYER NAME': 'Allen Robinson',
#   'TEAM': 'CHI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.5,
#   'SEPAverage Separation (SEP)': 2.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 25.01,
#   'RECReceptions (REC)': 55,
#   'TARTargets (TAR)': 94,
#   'CTCH%Catch Percentage (CTCH%)': 58.51,
#   'YDSReceiving Yards (YDS)': 754,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.1,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'Robby Anderson',
#   'TEAM': 'NYJ',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.4,
#   'SEPAverage Separation (SEP)': 2.3,
#   'TAYAverage Targeted Air Yards (TAY)': 16.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 33.6,
#   'RECReceptions (REC)': 50,
#   'TARTargets (TAR)': 94,
#   'CTCH%Catch Percentage (CTCH%)': 53.19,
#   'YDSReceiving Yards (YDS)': 752,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 3.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.3,
#   '+/-Avg .YAC Above Expectation': -0.6},
#  {'PLAYER NAME': 'Eric Ebron',
#   'TEAM': 'IND',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 3.4,
#   'TAYAverage Targeted Air Yards (TAY)': 9.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.0,
#   'RECReceptions (REC)': 66,
#   'TARTargets (TAR)': 110,
#   'CTCH%Catch Percentage (CTCH%)': 60.0,
#   'YDSReceiving Yards (YDS)': 750,
#   'TDReceiving Touchdowns (TD)': 13,
#   'YAC/RYAC/Reception (YAC/R)': 3.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': -1.0},
#  {'PLAYER NAME': 'Nelson Agholor',
#   'TEAM': 'PHI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 10.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 23.11,
#   'RECReceptions (REC)': 64,
#   'TARTargets (TAR)': 97,
#   'CTCH%Catch Percentage (CTCH%)': 65.98,
#   'YDSReceiving Yards (YDS)': 743,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 6.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.8,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'Jordy Nelson',
#   'TEAM': 'OAK',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 9.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 21.89,
#   'RECReceptions (REC)': 63,
#   'TARTargets (TAR)': 88,
#   'CTCH%Catch Percentage (CTCH%)': 71.59,
#   'YDSReceiving Yards (YDS)': 739,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 4.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': 0.0},
#  {'PLAYER NAME': 'Josh Gordon',
#   'TEAM': 'NE',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.7,
#   'SEPAverage Separation (SEP)': 2.1,
#   'TAYAverage Targeted Air Yards (TAY)': 14.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.96,
#   'RECReceptions (REC)': 41,
#   'TARTargets (TAR)': 71,
#   'CTCH%Catch Percentage (CTCH%)': 57.75,
#   'YDSReceiving Yards (YDS)': 737,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 7.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.1,
#   '+/-Avg .YAC Above Expectation': 3.0},
#  {'PLAYER NAME': 'Larry Fitzgerald',
#   'TEAM': 'ARI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 2.3,
#   'TAYAverage Targeted Air Yards (TAY)': 9.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 26.97,
#   'RECReceptions (REC)': 69,
#   'TARTargets (TAR)': 112,
#   'CTCH%Catch Percentage (CTCH%)': 61.61,
#   'YDSReceiving Yards (YDS)': 734,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 3.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.4,
#   '+/-Avg .YAC Above Expectation': -0.2},
#  {'PLAYER NAME': 'John Brown',
#   'TEAM': 'BAL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 2.3,
#   'TAYAverage Targeted Air Yards (TAY)': 16.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 33.84,
#   'RECReceptions (REC)': 42,
#   'TARTargets (TAR)': 97,
#   'CTCH%Catch Percentage (CTCH%)': 43.3,
#   'YDSReceiving Yards (YDS)': 717,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 4.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.8,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Dede Westbrook',
#   'TEAM': 'JAX',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.1,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 8.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 23.1,
#   'RECReceptions (REC)': 66,
#   'TARTargets (TAR)': 101,
#   'CTCH%Catch Percentage (CTCH%)': 65.35,
#   'YDSReceiving Yards (YDS)': 715,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 5.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'Courtland Sutton',
#   'TEAM': 'DEN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.6,
#   'SEPAverage Separation (SEP)': 2.2,
#   'TAYAverage Targeted Air Yards (TAY)': 14.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 27.51,
#   'RECReceptions (REC)': 42,
#   'TARTargets (TAR)': 84,
#   'CTCH%Catch Percentage (CTCH%)': 50.0,
#   'YDSReceiving Yards (YDS)': 704,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.5,
#   '+/-Avg .YAC Above Expectation': -0.1},
#  {'PLAYER NAME': 'A.J. Green',
#   'TEAM': 'CIN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.4,
#   'SEPAverage Separation (SEP)': 2.0,
#   'TAYAverage Targeted Air Yards (TAY)': 12.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.16,
#   'RECReceptions (REC)': 46,
#   'TARTargets (TAR)': 77,
#   'CTCH%Catch Percentage (CTCH%)': 59.74,
#   'YDSReceiving Yards (YDS)': 694,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 4.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.7,
#   '+/-Avg .YAC Above Expectation': -0.4},
#  {'PLAYER NAME': 'Taylor Gabriel',
#   'TEAM': 'CHI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 7.0,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 11.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 23.0,
#   'RECReceptions (REC)': 67,
#   'TARTargets (TAR)': 93,
#   'CTCH%Catch Percentage (CTCH%)': 72.04,
#   'YDSReceiving Yards (YDS)': 688,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 3.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.1,
#   '+/-Avg .YAC Above Expectation': -1.6},
#  {'PLAYER NAME': 'Rob Gronkowski',
#   'TEAM': 'NE',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.1,
#   'SEPAverage Separation (SEP)': 2.6,
#   'TAYAverage Targeted Air Yards (TAY)': 12.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 20.0,
#   'RECReceptions (REC)': 47,
#   'TARTargets (TAR)': 72,
#   'CTCH%Catch Percentage (CTCH%)': 65.28,
#   'YDSReceiving Yards (YDS)': 682,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 4.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.6,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Demaryius Thomas',
#   'TEAM': 'HOU',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 10.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 21.05,
#   'RECReceptions (REC)': 59,
#   'TARTargets (TAR)': 89,
#   'CTCH%Catch Percentage (CTCH%)': 66.29,
#   'YDSReceiving Yards (YDS)': 677,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 4.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Donte Moncrief',
#   'TEAM': 'JAX',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 2.2,
#   'TAYAverage Targeted Air Yards (TAY)': 12.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 30.85,
#   'RECReceptions (REC)': 48,
#   'TARTargets (TAR)': 89,
#   'CTCH%Catch Percentage (CTCH%)': 53.93,
#   'YDSReceiving Yards (YDS)': 672,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 5.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.9,
#   '+/-Avg .YAC Above Expectation': 1.3},
#  {'PLAYER NAME': 'Cole Beasley',
#   'TEAM': 'DAL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.9,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 7.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 16.1,
#   'RECReceptions (REC)': 65,
#   'TARTargets (TAR)': 87,
#   'CTCH%Catch Percentage (CTCH%)': 74.71,
#   'YDSReceiving Yards (YDS)': 672,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 3.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': -0.8},
#  {'PLAYER NAME': 'Mike Williams',
#   'TEAM': 'LAC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.9,
#   'SEPAverage Separation (SEP)': 2.1,
#   'TAYAverage Targeted Air Yards (TAY)': 15.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 24.85,
#   'RECReceptions (REC)': 43,
#   'TARTargets (TAR)': 66,
#   'CTCH%Catch Percentage (CTCH%)': 65.15,
#   'YDSReceiving Yards (YDS)': 664,
#   'TDReceiving Touchdowns (TD)': 10,
#   'YAC/RYAC/Reception (YAC/R)': 3.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.4,
#   '+/-Avg .YAC Above Expectation': -0.4},
#  {'PLAYER NAME': 'Austin Hooper',
#   'TEAM': 'ATL',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 3.2,
#   'TAYAverage Targeted Air Yards (TAY)': 6.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 11.26,
#   'RECReceptions (REC)': 71,
#   'TARTargets (TAR)': 88,
#   'CTCH%Catch Percentage (CTCH%)': 80.68,
#   'YDSReceiving Yards (YDS)': 660,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 3.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.9,
#   '+/-Avg .YAC Above Expectation': -0.4},
#  {'PLAYER NAME': 'Tyrell Williams',
#   'TEAM': 'LAC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.8,
#   'TAYAverage Targeted Air Yards (TAY)': 12.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 20.15,
#   'RECReceptions (REC)': 41,
#   'TARTargets (TAR)': 65,
#   'CTCH%Catch Percentage (CTCH%)': 63.08,
#   'YDSReceiving Yards (YDS)': 653,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 5.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.5,
#   '+/-Avg .YAC Above Expectation': -1.3},
#  {'PLAYER NAME': 'Zay Jones',
#   'TEAM': 'BUF',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 2.8,
#   'TAYAverage Targeted Air Yards (TAY)': 12.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 25.92,
#   'RECReceptions (REC)': 56,
#   'TARTargets (TAR)': 102,
#   'CTCH%Catch Percentage (CTCH%)': 54.9,
#   'YDSReceiving Yards (YDS)': 652,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 2.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 2.9,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Willie Snead',
#   'TEAM': 'BAL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 8.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 16.85,
#   'RECReceptions (REC)': 62,
#   'TARTargets (TAR)': 95,
#   'CTCH%Catch Percentage (CTCH%)': 65.26,
#   'YDSReceiving Yards (YDS)': 651,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 4.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.5,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'David Njoku',
#   'TEAM': 'CLE',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 8.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 14.12,
#   'RECReceptions (REC)': 56,
#   'TARTargets (TAR)': 88,
#   'CTCH%Catch Percentage (CTCH%)': 63.64,
#   'YDSReceiving Yards (YDS)': 639,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 6.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.0,
#   '+/-Avg .YAC Above Expectation': 1.1},
#  {'PLAYER NAME': 'Jimmy Graham',
#   'TEAM': 'GB',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 14.67,
#   'RECReceptions (REC)': 55,
#   'TARTargets (TAR)': 89,
#   'CTCH%Catch Percentage (CTCH%)': 61.8,
#   'YDSReceiving Yards (YDS)': 636,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 5.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.2,
#   '+/-Avg .YAC Above Expectation': -0.2},
#  {'PLAYER NAME': 'Kyle Rudolph',
#   'TEAM': 'MIN',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 6.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 12.58,
#   'RECReceptions (REC)': 64,
#   'TARTargets (TAR)': 82,
#   'CTCH%Catch Percentage (CTCH%)': 78.05,
#   'YDSReceiving Yards (YDS)': 634,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.7,
#   '+/-Avg .YAC Above Expectation': -0.6},
#  {'PLAYER NAME': 'Doug Baldwin',
#   'TEAM': 'SEA',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.2,
#   'SEPAverage Separation (SEP)': 2.8,
#   'TAYAverage Targeted Air Yards (TAY)': 12.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 22.87,
#   'RECReceptions (REC)': 50,
#   'TARTargets (TAR)': 73,
#   'CTCH%Catch Percentage (CTCH%)': 68.49,
#   'YDSReceiving Yards (YDS)': 618,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 3.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.7,
#   '+/-Avg .YAC Above Expectation': 0.0},
#  {'PLAYER NAME': 'Vance McDonald',
#   'TEAM': 'PIT',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.5,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 5.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 7.84,
#   'RECReceptions (REC)': 50,
#   'TARTargets (TAR)': 72,
#   'CTCH%Catch Percentage (CTCH%)': 69.44,
#   'YDSReceiving Yards (YDS)': 610,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 7.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.9,
#   '+/-Avg .YAC Above Expectation': 2.1},
#  {'PLAYER NAME': 'Michael Crabtree',
#   'TEAM': 'BAL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.3,
#   'SEPAverage Separation (SEP)': 2.8,
#   'TAYAverage Targeted Air Yards (TAY)': 10.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 23.09,
#   'RECReceptions (REC)': 54,
#   'TARTargets (TAR)': 100,
#   'CTCH%Catch Percentage (CTCH%)': 54.0,
#   'YDSReceiving Yards (YDS)': 607,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 2.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.4,
#   '+/-Avg .YAC Above Expectation': -1.7},
#  {'PLAYER NAME': 'Christian Kirk',
#   'TEAM': 'ARI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 9.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 16.65,
#   'RECReceptions (REC)': 43,
#   'TARTargets (TAR)': 68,
#   'CTCH%Catch Percentage (CTCH%)': 63.24,
#   'YDSReceiving Yards (YDS)': 590,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 5.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Antonio Callaway',
#   'TEAM': 'CLE',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.0,
#   'SEPAverage Separation (SEP)': 2.6,
#   'TAYAverage Targeted Air Yards (TAY)': 13.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 20.44,
#   'RECReceptions (REC)': 43,
#   'TARTargets (TAR)': 79,
#   'CTCH%Catch Percentage (CTCH%)': 54.43,
#   'YDSReceiving Yards (YDS)': 586,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 5.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.5,
#   '+/-Avg .YAC Above Expectation': -0.7},
#  {'PLAYER NAME': 'Marquez Valdes-Scantling',
#   'TEAM': 'GB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 12.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 16.26,
#   'RECReceptions (REC)': 38,
#   'TARTargets (TAR)': 73,
#   'CTCH%Catch Percentage (CTCH%)': 52.05,
#   'YDSReceiving Yards (YDS)': 581,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 6.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.1,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Evan Engram',
#   'TEAM': 'NYG',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.1,
#   'SEPAverage Separation (SEP)': 4.4,
#   'TAYAverage Targeted Air Yards (TAY)': 5.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 7.62,
#   'RECReceptions (REC)': 45,
#   'TARTargets (TAR)': 64,
#   'CTCH%Catch Percentage (CTCH%)': 70.31,
#   'YDSReceiving Yards (YDS)': 577,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 9.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.1,
#   '+/-Avg .YAC Above Expectation': 2.9},
#  {'PLAYER NAME': 'Danny Amendola',
#   'TEAM': 'MIA',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 3.2,
#   'TAYAverage Targeted Air Yards (TAY)': 7.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.62,
#   'RECReceptions (REC)': 59,
#   'TARTargets (TAR)': 79,
#   'CTCH%Catch Percentage (CTCH%)': 74.68,
#   'YDSReceiving Yards (YDS)': 575,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 4.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.4,
#   '+/-Avg .YAC Above Expectation': -1.3},
#  {'PLAYER NAME': 'Rashard Higgins',
#   'TEAM': 'CLE',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.5,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 11.19,
#   'RECReceptions (REC)': 39,
#   'TARTargets (TAR)': 53,
#   'CTCH%Catch Percentage (CTCH%)': 73.58,
#   'YDSReceiving Yards (YDS)': 572,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 4.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.4,
#   '+/-Avg .YAC Above Expectation': -0.2},
#  {'PLAYER NAME': 'Trey Burton',
#   'TEAM': 'CHI',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 3.4,
#   'TAYAverage Targeted Air Yards (TAY)': 8.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 13.72,
#   'RECReceptions (REC)': 54,
#   'TARTargets (TAR)': 76,
#   'CTCH%Catch Percentage (CTCH%)': 71.05,
#   'YDSReceiving Yards (YDS)': 569,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 3.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Cooper Kupp',
#   'TEAM': 'LAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.7,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 8.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 9.62,
#   'RECReceptions (REC)': 40,
#   'TARTargets (TAR)': 55,
#   'CTCH%Catch Percentage (CTCH%)': 72.73,
#   'YDSReceiving Yards (YDS)': 566,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 7.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 7.4,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'O.J. Howard',
#   'TEAM': 'TB',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 4.5,
#   'SEPAverage Separation (SEP)': 2.5,
#   'TAYAverage Targeted Air Yards (TAY)': 11.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 8.11,
#   'RECReceptions (REC)': 34,
#   'TARTargets (TAR)': 48,
#   'CTCH%Catch Percentage (CTCH%)': 70.83,
#   'YDSReceiving Yards (YDS)': 565,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 6.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': 2.0},
#  {'PLAYER NAME': 'Jordan Reed',
#   'TEAM': 'WAS',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.6,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 6.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 13.36,
#   'RECReceptions (REC)': 54,
#   'TARTargets (TAR)': 84,
#   'CTCH%Catch Percentage (CTCH%)': 64.29,
#   'YDSReceiving Yards (YDS)': 558,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Kenny Stills',
#   'TEAM': 'MIA',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 2.4,
#   'TAYAverage Targeted Air Yards (TAY)': 16.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 29.53,
#   'RECReceptions (REC)': 37,
#   'TARTargets (TAR)': 64,
#   'CTCH%Catch Percentage (CTCH%)': 57.81,
#   'YDSReceiving Yards (YDS)': 553,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 3.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.3,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'Mark Andrews',
#   'TEAM': 'BAL',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.2,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 10.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 11.16,
#   'RECReceptions (REC)': 34,
#   'TARTargets (TAR)': 50,
#   'CTCH%Catch Percentage (CTCH%)': 68.0,
#   'YDSReceiving Yards (YDS)': 552,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 6.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.6,
#   '+/-Avg .YAC Above Expectation': 0.8},
#  {'PLAYER NAME': 'Devin Funchess',
#   'TEAM': 'CAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.0,
#   'SEPAverage Separation (SEP)': 2.3,
#   'TAYAverage Targeted Air Yards (TAY)': 12.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 24.21,
#   'RECReceptions (REC)': 44,
#   'TARTargets (TAR)': 79,
#   'CTCH%Catch Percentage (CTCH%)': 55.7,
#   'YDSReceiving Yards (YDS)': 549,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 1.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 2.6,
#   '+/-Avg .YAC Above Expectation': -0.8},
#  {'PLAYER NAME': 'Chris Hogan',
#   'TEAM': 'NE',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 4.1,
#   'TAYAverage Targeted Air Yards (TAY)': 12.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.28,
#   'RECReceptions (REC)': 35,
#   'TARTargets (TAR)': 55,
#   'CTCH%Catch Percentage (CTCH%)': 63.64,
#   'YDSReceiving Yards (YDS)': 532,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 6.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.7,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Josh Doctson',
#   'TEAM': 'WAS',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.4,
#   'TAYAverage Targeted Air Yards (TAY)': 14.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 26.8,
#   'RECReceptions (REC)': 44,
#   'TARTargets (TAR)': 78,
#   'CTCH%Catch Percentage (CTCH%)': 56.41,
#   'YDSReceiving Yards (YDS)': 532,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 3.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.5,
#   '+/-Avg .YAC Above Expectation': -0.2},
#  {'PLAYER NAME': 'Robert Foster',
#   'TEAM': 'BUF',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 20.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 17.77,
#   'RECReceptions (REC)': 26,
#   'TARTargets (TAR)': 43,
#   'CTCH%Catch Percentage (CTCH%)': 60.47,
#   'YDSReceiving Yards (YDS)': 526,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 6.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.4,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Sammy Watkins',
#   'TEAM': 'KC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.5,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 8.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 8.7,
#   'RECReceptions (REC)': 40,
#   'TARTargets (TAR)': 55,
#   'CTCH%Catch Percentage (CTCH%)': 72.73,
#   'YDSReceiving Yards (YDS)': 519,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 6.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.8,
#   '+/-Avg .YAC Above Expectation': -0.6},
#  {'PLAYER NAME': 'Marvin Jones',
#   'TEAM': 'DET',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 4.0,
#   'SEPAverage Separation (SEP)': 2.2,
#   'TAYAverage Targeted Air Yards (TAY)': 15.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 23.54,
#   'RECReceptions (REC)': 35,
#   'TARTargets (TAR)': 62,
#   'CTCH%Catch Percentage (CTCH%)': 56.45,
#   'YDSReceiving Yards (YDS)': 508,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 3.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 2.3,
#   '+/-Avg .YAC Above Expectation': 0.8},
#  {'PLAYER NAME': 'Michael Gallup',
#   'TEAM': 'DAL',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.3,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 14.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 23.78,
#   'RECReceptions (REC)': 33,
#   'TARTargets (TAR)': 68,
#   'CTCH%Catch Percentage (CTCH%)': 48.53,
#   'YDSReceiving Yards (YDS)': 507,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 5.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.1,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Will Fuller',
#   'TEAM': 'HOU',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 14.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 14.93,
#   'RECReceptions (REC)': 32,
#   'TARTargets (TAR)': 45,
#   'CTCH%Catch Percentage (CTCH%)': 71.11,
#   'YDSReceiving Yards (YDS)': 503,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 5.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.2,
#   '+/-Avg .YAC Above Expectation': 0.3},
#  {'PLAYER NAME': 'Chris Herndon',
#   'TEAM': 'NYJ',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 10.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 12.08,
#   'RECReceptions (REC)': 39,
#   'TARTargets (TAR)': 56,
#   'CTCH%Catch Percentage (CTCH%)': 69.64,
#   'YDSReceiving Yards (YDS)': 502,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 5.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': -0.3},
#  {'PLAYER NAME': 'Curtis Samuel',
#   'TEAM': 'CAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.7,
#   'SEPAverage Separation (SEP)': 2.4,
#   'TAYAverage Targeted Air Yards (TAY)': 12.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 19.14,
#   'RECReceptions (REC)': 39,
#   'TARTargets (TAR)': 65,
#   'CTCH%Catch Percentage (CTCH%)': 60.0,
#   'YDSReceiving Yards (YDS)': 494,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 2.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.3,
#   '+/-Avg .YAC Above Expectation': -0.4},
#  {'PLAYER NAME': 'Seth Roberts',
#   'TEAM': 'OAK',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.4,
#   'SEPAverage Separation (SEP)': 3.2,
#   'TAYAverage Targeted Air Yards (TAY)': 8.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 14.46,
#   'RECReceptions (REC)': 45,
#   'TARTargets (TAR)': 64,
#   'CTCH%Catch Percentage (CTCH%)': 70.31,
#   'YDSReceiving Yards (YDS)': 494,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 5.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'Keelan Cole',
#   'TEAM': 'JAX',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.6,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 18.31,
#   'RECReceptions (REC)': 38,
#   'TARTargets (TAR)': 70,
#   'CTCH%Catch Percentage (CTCH%)': 54.29,
#   'YDSReceiving Yards (YDS)': 491,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 3.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.7,
#   '+/-Avg .YAC Above Expectation': -0.8},
#  {'PLAYER NAME': 'Kendrick Bourne',
#   'TEAM': 'SF',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.5,
#   'SEPAverage Separation (SEP)': 2.8,
#   'TAYAverage Targeted Air Yards (TAY)': 9.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.4,
#   'RECReceptions (REC)': 42,
#   'TARTargets (TAR)': 67,
#   'CTCH%Catch Percentage (CTCH%)': 62.69,
#   'YDSReceiving Yards (YDS)': 487,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 3.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.5,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Chester Rogers',
#   'TEAM': 'IND',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 3.6,
#   'TAYAverage Targeted Air Yards (TAY)': 6.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 9.32,
#   'RECReceptions (REC)': 53,
#   'TARTargets (TAR)': 72,
#   'CTCH%Catch Percentage (CTCH%)': 73.61,
#   'YDSReceiving Yards (YDS)': 485,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 5.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.9,
#   '+/-Avg .YAC Above Expectation': -0.8},
#  {'PLAYER NAME': 'Dante Pettis',
#   'TEAM': 'SF',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 3.4,
#   'TAYAverage Targeted Air Yards (TAY)': 11.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 13.52,
#   'RECReceptions (REC)': 27,
#   'TARTargets (TAR)': 45,
#   'CTCH%Catch Percentage (CTCH%)': 60.0,
#   'YDSReceiving Yards (YDS)': 467,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 7.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.7,
#   '+/-Avg .YAC Above Expectation': 1.9},
# ...
#  {'PLAYER NAME': "Tre'Quan Smith",
#   'TEAM': 'NO',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.2,
#   'TAYAverage Targeted Air Yards (TAY)': 12.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 14.26,
#   'RECReceptions (REC)': 28,
#   'TARTargets (TAR)': 44,
#   'CTCH%Catch Percentage (CTCH%)': 63.64,
#   'YDSReceiving Yards (YDS)': 427,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 4.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.5,
#   '+/-Avg .YAC Above Expectation': 0.7},
#  {'PLAYER NAME': 'Anthony Miller',
#   'TEAM': 'CHI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.2,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 13.71,
#   'RECReceptions (REC)': 33,
#   'TARTargets (TAR)': 54,
#   'CTCH%Catch Percentage (CTCH%)': 61.11,
#   'YDSReceiving Yards (YDS)': 423,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 5.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.9,
#   '+/-Avg .YAC Above Expectation': 0.5},
#  {'PLAYER NAME': 'Josh Reynolds',
#   'TEAM': 'LAR',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 7.5,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 12.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 13.64,
#   'RECReceptions (REC)': 29,
#   'TARTargets (TAR)': 52,
#   'CTCH%Catch Percentage (CTCH%)': 55.77,
#   'YDSReceiving Yards (YDS)': 402,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 4.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.2,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Benjamin Watson',
#   'TEAM': 'NO',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 2.6,
#   'TAYAverage Targeted Air Yards (TAY)': 9.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 12.21,
#   'RECReceptions (REC)': 35,
#   'TARTargets (TAR)': 46,
#   'CTCH%Catch Percentage (CTCH%)': 76.09,
#   'YDSReceiving Yards (YDS)': 400,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 3.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.2,
#   '+/-Avg .YAC Above Expectation': -1.1},
#  {'PLAYER NAME': 'Marquise Goodwin',
#   'TEAM': 'SF',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 14.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.89,
#   'RECReceptions (REC)': 23,
#   'TARTargets (TAR)': 44,
#   'CTCH%Catch Percentage (CTCH%)': 52.27,
#   'YDSReceiving Yards (YDS)': 395,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 5.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.9,
#   '+/-Avg .YAC Above Expectation': 2.0},
#  {'PLAYER NAME': 'Jamison Crowder',
#   'TEAM': 'WAS',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.4,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 9.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 10.71,
#   'RECReceptions (REC)': 29,
#   'TARTargets (TAR)': 49,
#   'CTCH%Catch Percentage (CTCH%)': 59.18,
#   'YDSReceiving Yards (YDS)': 388,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 7.6,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.7,
#   '+/-Avg .YAC Above Expectation': 1.0},
#  {'PLAYER NAME': 'Randall Cobb',
#   'TEAM': 'GB',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 8.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 8.84,
#   'RECReceptions (REC)': 38,
#   'TARTargets (TAR)': 61,
#   'CTCH%Catch Percentage (CTCH%)': 62.3,
#   'YDSReceiving Yards (YDS)': 383,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 6.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.3,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'Kelvin Benjamin',
#   'TEAM': 'KC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.5,
#   'SEPAverage Separation (SEP)': 1.7,
#   'TAYAverage Targeted Air Yards (TAY)': 15.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 21.41,
#   'RECReceptions (REC)': 25,
#   'TARTargets (TAR)': 67,
#   'CTCH%Catch Percentage (CTCH%)': 37.31,
#   'YDSReceiving Yards (YDS)': 380,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 2.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 2.9,
#   '+/-Avg .YAC Above Expectation': -0.1},
#  {'PLAYER NAME': 'Jermaine Kearse',
#   'TEAM': 'NYJ',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.4,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 9.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.34,
#   'RECReceptions (REC)': 37,
#   'TARTargets (TAR)': 76,
#   'CTCH%Catch Percentage (CTCH%)': 48.68,
#   'YDSReceiving Yards (YDS)': 371,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 3.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.3,
#   '+/-Avg .YAC Above Expectation': 0.4},
#  {'PLAYER NAME': 'Ricky Seals-Jones',
#   'TEAM': 'ARI',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.3,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 9.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 17.05,
#   'RECReceptions (REC)': 34,
#   'TARTargets (TAR)': 69,
#   'CTCH%Catch Percentage (CTCH%)': 49.28,
#   'YDSReceiving Yards (YDS)': 343,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 3.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.4,
#   '+/-Avg .YAC Above Expectation': -0.4},
#  {'PLAYER NAME': 'Chris Conley',
#   'TEAM': 'KC',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.5,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 9.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 9.35,
#   'RECReceptions (REC)': 32,
#   'TARTargets (TAR)': 52,
#   'CTCH%Catch Percentage (CTCH%)': 61.54,
#   'YDSReceiving Yards (YDS)': 334,
#   'TDReceiving Touchdowns (TD)': 5,
#   'YAC/RYAC/Reception (YAC/R)': 4.3,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.8,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Ryan Grant',
#   'TEAM': 'IND',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 2.6,
#   'TAYAverage Targeted Air Yards (TAY)': 9.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 10.05,
#   'RECReceptions (REC)': 35,
#   'TARTargets (TAR)': 52,
#   'CTCH%Catch Percentage (CTCH%)': 67.31,
#   'YDSReceiving Yards (YDS)': 334,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 2.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.2,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Dallas Goedert',
#   'TEAM': 'PHI',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.2,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 7.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 7.74,
#   'RECReceptions (REC)': 33,
#   'TARTargets (TAR)': 44,
#   'CTCH%Catch Percentage (CTCH%)': 75.0,
#   'YDSReceiving Yards (YDS)': 334,
#   'TDReceiving Touchdowns (TD)': 4,
#   'YAC/RYAC/Reception (YAC/R)': 5.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': 0.1},
#  {'PLAYER NAME': 'Ian Thomas',
#   'TEAM': 'CAR',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.0,
#   'SEPAverage Separation (SEP)': 3.4,
#   'TAYAverage Targeted Air Yards (TAY)': 6.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 7.46,
#   'RECReceptions (REC)': 36,
#   'TARTargets (TAR)': 49,
#   'CTCH%Catch Percentage (CTCH%)': 73.47,
#   'YDSReceiving Yards (YDS)': 333,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 4.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.1,
#   '+/-Avg .YAC Above Expectation': -0.6},
#  {'PLAYER NAME': 'Antonio Gates',
#   'TEAM': 'LAC',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 4.4,
#   'SEPAverage Separation (SEP)': 2.5,
#   'TAYAverage Targeted Air Yards (TAY)': 8.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 9.81,
#   'RECReceptions (REC)': 28,
#   'TARTargets (TAR)': 45,
#   'CTCH%Catch Percentage (CTCH%)': 62.22,
#   'YDSReceiving Yards (YDS)': 333,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.9,
#   '+/-Avg .YAC Above Expectation': 0.6},
#  {'PLAYER NAME': 'Tajae Sharpe',
#   'TEAM': 'TEN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.2,
#   'SEPAverage Separation (SEP)': 3.0,
#   'TAYAverage Targeted Air Yards (TAY)': 11.3,
#   "TAY%% Share of Team's Air Yards (TAY%)": 16.55,
#   'RECReceptions (REC)': 26,
#   'TARTargets (TAR)': 47,
#   'CTCH%Catch Percentage (CTCH%)': 55.32,
#   'YDSReceiving Yards (YDS)': 316,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 3.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.2,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'Gerald Everett',
#   'TEAM': 'LAR',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 6.0,
#   'SEPAverage Separation (SEP)': 3.9,
#   'TAYAverage Targeted Air Yards (TAY)': 6.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 6.56,
#   'RECReceptions (REC)': 32,
#   'TARTargets (TAR)': 49,
#   'CTCH%Catch Percentage (CTCH%)': 65.31,
#   'YDSReceiving Yards (YDS)': 313,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.0,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'DeVante Parker',
#   'TEAM': 'MIA',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.2,
#   'SEPAverage Separation (SEP)': 2.7,
#   'TAYAverage Targeted Air Yards (TAY)': 11.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.34,
#   'RECReceptions (REC)': 24,
#   'TARTargets (TAR)': 47,
#   'CTCH%Catch Percentage (CTCH%)': 51.06,
#   'YDSReceiving Yards (YDS)': 306,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 4.5,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': -1.0},
#  {'PLAYER NAME': 'Ryan Griffin',
#   'TEAM': 'HOU',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.1,
#   'SEPAverage Separation (SEP)': 3.4,
#   'TAYAverage Targeted Air Yards (TAY)': 7.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 7.71,
#   'RECReceptions (REC)': 24,
#   'TARTargets (TAR)': 43,
#   'CTCH%Catch Percentage (CTCH%)': 55.81,
#   'YDSReceiving Yards (YDS)': 305,
#   'TDReceiving Touchdowns (TD)': 0,
#   'YAC/RYAC/Reception (YAC/R)': 6.8,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 6.5,
#   '+/-Avg .YAC Above Expectation': 0.2},
#  {'PLAYER NAME': 'Maurice Harris',
#   'TEAM': 'WAS',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.6,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 10.5,
#   "TAY%% Share of Team's Air Yards (TAY%)": 11.85,
#   'RECReceptions (REC)': 28,
#   'TARTargets (TAR)': 47,
#   'CTCH%Catch Percentage (CTCH%)': 59.57,
#   'YDSReceiving Yards (YDS)': 304,
#   'TDReceiving Touchdowns (TD)': 0,
#   'YAC/RYAC/Reception (YAC/R)': 3.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': -2.2},
#  {'PLAYER NAME': 'Laquon Treadwell',
#   'TEAM': 'MIN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 6.3,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 5.9,
#   "TAY%% Share of Team's Air Yards (TAY%)": 7.02,
#   'RECReceptions (REC)': 35,
#   'TARTargets (TAR)': 53,
#   'CTCH%Catch Percentage (CTCH%)': 66.04,
#   'YDSReceiving Yards (YDS)': 302,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 3.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.4,
#   '+/-Avg .YAC Above Expectation': 0.0},
#  {'PLAYER NAME': 'Cameron Brate',
#   'TEAM': 'TB',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.9,
#   'TAYAverage Targeted Air Yards (TAY)': 8.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 6.46,
#   'RECReceptions (REC)': 30,
#   'TARTargets (TAR)': 49,
#   'CTCH%Catch Percentage (CTCH%)': 61.22,
#   'YDSReceiving Yards (YDS)': 289,
#   'TDReceiving Touchdowns (TD)': 6,
#   'YAC/RYAC/Reception (YAC/R)': 2.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 2.8,
#   '+/-Avg .YAC Above Expectation': -0.7},
#  {'PLAYER NAME': 'Pierre Garcon',
#   'TEAM': 'SF',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.6,
#   'SEPAverage Separation (SEP)': 2.8,
#   'TAYAverage Targeted Air Yards (TAY)': 8.8,
#   "TAY%% Share of Team's Air Yards (TAY%)": 10.29,
#   'RECReceptions (REC)': 24,
#   'TARTargets (TAR)': 46,
#   'CTCH%Catch Percentage (CTCH%)': 52.17,
#   'YDSReceiving Yards (YDS)': 286,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 4.7,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': -0.6},
#  {'PLAYER NAME': 'Jeff Heuerman',
#   'TEAM': 'DEN',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 3.3,
#   'TAYAverage Targeted Air Yards (TAY)': 5.7,
#   "TAY%% Share of Team's Air Yards (TAY%)": 6.25,
#   'RECReceptions (REC)': 31,
#   'TARTargets (TAR)': 48,
#   'CTCH%Catch Percentage (CTCH%)': 64.58,
#   'YDSReceiving Yards (YDS)': 281,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 5.0,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.5,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Nick Vannett',
#   'TEAM': 'SEA',
#   'POS': 'TE',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 3.7,
#   'TAYAverage Targeted Air Yards (TAY)': 6.1,
#   "TAY%% Share of Team's Air Yards (TAY%)": 6.77,
#   'RECReceptions (REC)': 29,
#   'TARTargets (TAR)': 43,
#   'CTCH%Catch Percentage (CTCH%)': 67.44,
#   'YDSReceiving Yards (YDS)': 269,
#   'TDReceiving Touchdowns (TD)': 3,
#   'YAC/RYAC/Reception (YAC/R)': 5.2,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': 0.0},
#  {'PLAYER NAME': 'Zach Pascal',
#   'TEAM': 'IND',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.7,
#   'SEPAverage Separation (SEP)': 2.4,
#   'TAYAverage Targeted Air Yards (TAY)': 9.6,
#   "TAY%% Share of Team's Air Yards (TAY%)": 8.95,
#   'RECReceptions (REC)': 27,
#   'TARTargets (TAR)': 46,
#   'CTCH%Catch Percentage (CTCH%)': 58.7,
#   'YDSReceiving Yards (YDS)': 268,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 3.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 4.0,
#   '+/-Avg .YAC Above Expectation': -0.9},
#  {'PLAYER NAME': 'Ryan Switzer',
#   'TEAM': 'PIT',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.8,
#   'SEPAverage Separation (SEP)': 3.5,
#   'TAYAverage Targeted Air Yards (TAY)': 3.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 2.66,
#   'RECReceptions (REC)': 36,
#   'TARTargets (TAR)': 44,
#   'CTCH%Catch Percentage (CTCH%)': 81.82,
#   'YDSReceiving Yards (YDS)': 253,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 4.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 5.3,
#   '+/-Avg .YAC Above Expectation': -1.2},
#  {'PLAYER NAME': 'DaeSean Hamilton',
#   'TEAM': 'DEN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.3,
#   'SEPAverage Separation (SEP)': 3.1,
#   'TAYAverage Targeted Air Yards (TAY)': 8.4,
#   "TAY%% Share of Team's Air Yards (TAY%)": 8.8,
#   'RECReceptions (REC)': 30,
#   'TARTargets (TAR)': 46,
#   'CTCH%Catch Percentage (CTCH%)': 65.22,
#   'YDSReceiving Yards (YDS)': 243,
#   'TDReceiving Touchdowns (TD)': 2,
#   'YAC/RYAC/Reception (YAC/R)': 2.4,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.6,
#   '+/-Avg .YAC Above Expectation': -1.2},
#  {'PLAYER NAME': 'John Ross',
#   'TEAM': 'CIN',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 2.2,
#   'TAYAverage Targeted Air Yards (TAY)': 14.0,
#   "TAY%% Share of Team's Air Yards (TAY%)": 18.36,
#   'RECReceptions (REC)': 21,
#   'TARTargets (TAR)': 58,
#   'CTCH%Catch Percentage (CTCH%)': 36.21,
#   'YDSReceiving Yards (YDS)': 210,
#   'TDReceiving Touchdowns (TD)': 7,
#   'YAC/RYAC/Reception (YAC/R)': 3.1,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 3.6,
#   '+/-Avg .YAC Above Expectation': -0.5},
#  {'PLAYER NAME': 'Chad Williams',
#   'TEAM': 'ARI',
#   'POS': 'WR',
#   'CUSHAverage Cushion (CUSH)': 5.4,
#   'SEPAverage Separation (SEP)': 1.9,
#   'TAYAverage Targeted Air Yards (TAY)': 13.2,
#   "TAY%% Share of Team's Air Yards (TAY%)": 15.27,
#   'RECReceptions (REC)': 17,
#   'TARTargets (TAR)': 46,
#   'CTCH%Catch Percentage (CTCH%)': 36.96,
#   'YDSReceiving Yards (YDS)': 171,
#   'TDReceiving Touchdowns (TD)': 1,
#   'YAC/RYAC/Reception (YAC/R)': 0.9,
#   'xYAC/RExpected YAC/Reception (EYAC/R)': 1.3,
#   '+/-Avg .YAC Above Expectation': -0.4}]
